# %%
import pandas as pd
    
ds = pd.read_csv('job.csv')
ds.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0                Customer Care Proffessional (Voice)
# 1           1               newFreelance Writer - Work from Home
# 2           2         Online Maths/Science Tutor for grades(1-7)
# 3           3                                  Computer Operator
# 4           4  newFresher Hiring for documents verification p...
#
#                       location  \
# 0             Gurgaon, Haryana
# 1       Remote in Delhi, Delhi
# 2                       Remote
# 3             New Delhi, Delhi
# 4  Malviya Nagar, Delhi, Delhi
#
#                                              summary  \
# 0  MS office suites such as Excel, Word, PowerPoi...
# 1  Submit a minimum of 5 articles (an average of ...
# 2  Taking a minimum of 3 Lectures in a day (Can t...
# 3  Job Types: Full-time, Part-time.\nExperience o...
# 4  Job Types: Full-time, Part-time, Regular / Per...
#
#                          salary
# ...

# %%
with open('job.csv', 'r') as f:
    for i in f:
        print((i))
    f.close()
# Out:
# ,title,location,summary,salary
#
# 0,Customer Care Proffessional (Voice),"Gurgaon, Haryana","MS office suites such as Excel, Word, PowerPoint.
#
# Enhance our customersвЂ™ experience by finding opportunities to offer products based on our CardmembersвЂ™ needs.","в‚№5,00,000 - в‚№9,50,000 a year"
#
# 1,newFreelance Writer - Work from Home,"Remote in Delhi, Delhi","Submit a minimum of 5 articles (an average of 1,000 words each) per month.
#
# Produce a minimum of 5 articles per month.
#
# Experience in writing travel content.","в‚№4,000 - в‚№15,000 a month"
#
# 2,Online Maths/Science Tutor for grades(1-7),Remote,"Taking a minimum of 3 Lectures in a day (Can take more if time permits) and a minimum of 6 days working (including weekends.
#
# Preferred timings 2 PM to 8 PM.",в‚№225 - в‚№350 an hour
#
# 3,Computer Operator,"New Delhi, Delhi","Job Types: Full-time, Part-time.
#
# Experience of Computers (MS Word, Excel, Power Point), Emails, Good Typing Speed.","в‚№6,000 - в‚№10,000 a month"
#
# 4,newFresher Hiring for documents verification process,"Malviya Nagar, Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent.
#
# Attend calls & revert to E-mails professionally to provide information about products and services, obtainвЂ¦","в‚№18,667 - в‚№34,655 a month"
#
# 5,Computer operater,"Delhi, Delhi",Computer operators *monitor and control computer and electronic data processing equipment according to standardized operating instructions*.,"в‚№12,000 a month"
#
# 6,newSpa Therapist,"Delhi, Delhi+1 location","Part-time hours: 15 per week.
#
# Candidate should possess good communication skill, must be hard working and flexible.
#
# Job Types: Full-time, Part-time.","в‚№52,000 - в‚№55,000 a month"
#
# 7,Data Entry Operator,"Lucknow, Uttar Pradesh","Knowledge Of computer is a must.
#
# Main work is, Data entry of Documents and Catalogues on the company server.
#
# Zero Experience Candidates can also apply.",в‚№25 - в‚№70 an hour
#
# 8,Freelance Content Writer,"Gurgaon, Haryana","Gurugram, Haryana: Reliably commute or planning to relocate before starting work (Required).
#
# Total work: 1 year (Preferred).","в‚№9,372 - в‚№40,473 a month"
#
# 9,Excel Project Developer-Contract Position,"Remote in Punjabi Bagh, Delhi, Delhi","In Spreadsheet we need to add hours with key in for each employee, studentsвЂ™ classes even when they weekly get the schedule on hourly basis and determineвЂ¦","в‚№8,000 - в‚№15,000 a week"
#
# 10,Urgent Requirement of Telecaller,"Tilak Nagar, Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Volunteer, Internship, Fresher.","в‚№15,000 - в‚№50,000 a month"
#
# 11,newWeb Content Writer,"Noida, Uttar Pradesh","Every website has a specific target audience and requires the most relevant content to attract business.
#
# We are looking to hire a A Website content writer orвЂ¦",в‚№8.56 - в‚№20.00 an hour
#
# 12,Academic Writer (Freelance),"Remote in Noida, Uttar Pradesh","The candidates must have good typing speed, the ability to write good quality content in English, the ability to do intensive research, a good understanding ofвЂ¦","в‚№10,000 - в‚№20,000 a month"
#
# 13,Data Entry Operator,"Darbhanga, Bihar","Required data entry operator with minimum speed 40.
#
# Part-time hours: 48 per week.
#
# Job Types: Full-time, Part-time, Contractual / Temporary, Freelance.","в‚№10,000 a month"
#
# 14,Content Writer,"Remote in Delhi, Delhi","Part-time hours: 56 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent.","в‚№21,000 a month"
#
# 15,newHR Recruiter,"Remote in Delhi, Delhi","Means he must be told how to do the establishment of communication and achieve the desired outcome.
#
# Part-time hours: 15 per week.",NA
#
# 16,newFront Desk Receptionist,"Ghaziabad, Uttar Pradesh","Part-time hours: 25 per week.
#
# Keep track of office supplies and place orders when required.
#
# Job Types: Part-time, Regular / Permanent, Fresher.","в‚№8,086 - в‚№10,000 a month"
#
# 17,newCall Center Executive,"New Delhi, Delhi","Part-time hours: 32 per week.
#
# Job Types: Full-time, Part-time, Freelance.
#
# Near Shanti palace hotel, New Delhi, Delhi: Reliably commute or planning to relocateвЂ¦","в‚№10,141 - в‚№15,000 a month"
#
# 18,Human Resources Internship,"Temporarily Remote in Delhi, Delhi+2 locations","All students pursuing under graduate degree/post graduate degree.
#
# Any graduate, digital marketing, social media marketing, email marketing.","в‚№6,000 - в‚№9,000 a month"
#
# 19,newQuality Analyst,"Chandigarh, Chandigarh","Analyse and verify customer accounts as per available data.
#
# Any Graduate or under-graduate with minimum 1 year of experience.","в‚№3,50,000 a month"
#
# 20,newCashier/Sales Assistant,"Delhi, Delhi","Job Types: Full-time, Part-time.
#
# Yes vivid protocols are followed.
#
# Delhi, Delhi - 110051, Delhi: Reliably commute or planning to relocate before starting work вЂ¦","в‚№12,000 - в‚№15,000 a month"
#
# 21,Social Media (Part-Time/Freelancer),"New Delhi, Delhi","Part-time hours: 5 per week.
#
# Job Types: Part-time, Contractual / Temporary, Freelance, Internship.
#
# Social media marketing: 1 year (Preferred).","в‚№7,000 - в‚№15,000 a month"
#
# 22,newHR Intern,"Remote in Noida, Uttar Pradesh","Attending all meeting on time.
#
# Job Types: Part-time, Internship, Fresher.
#
# Arranging Session and problem solving.
#
# Opening ( 2 in 1 ) Account in yes Bank.","в‚№7,000 a month"
#
# 23,newBUS HELPER,"Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Volunteer, Internship, Fresher.
#
# Total work: 1 year (Preferred).","в‚№9,391 - в‚№15,000 a month"
#
# 24,newComputer Teacher Required,"Delhi, Delhi","Part-time hours: 30 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Fresher.
#
# Total work: 1 year (Preferred).",NA
#
# 25,newComputer Operator,"Delhi, Delhi","Data entry: 1 year (Preferred).
#
# Part-time hours: 40 per week.
#
# Higher Secondary(12th Pass) (Required).
#
# Delhi, Delhi: Reliably commute or planning to relocateвЂ¦","в‚№8,000 - в‚№20,000 a month"
#
# 26,Model for Jewelry and Apparel,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent.
#
# Gurgaon, Gurgaon, Haryana: Reliably commute or planning to relocate before starting work (Preferred).","в‚№8,000 - в‚№25,000 a month"
#
# 27,newNews Reporter,"Ghaziabad, Uttar Pradesh","Skills needed for the job - English and Hindi typing, good vocabulary in any of the languages.
#
# Part-time hours: 72 per week.
#
# Total work: 10 years (Preferred).","в‚№5,000 - в‚№15,000 a month"
#
# 28,newFemale Hindi Online Tutor,Remote,"Teach students how to apply Grammar, how to write the hindi, explaining quality .
#
# Ability to manage time effectively.
#
# Total work: 1 year (Preferred).",в‚№200 an hour
#
# 29,newComputer Teacher,"Remote in Ranchi, Jharkhand",Part-time hours: 14 per week.,"в‚№20,000 a month"
#
# 30,Content Writer- Web,"Jaipur, Rajasthan","Job Types: Full-time, Part-time, Regular / Permanent, Freelance, Internship, Fresher.
#
# Copy-editing and proof reading articles.
#
# Total work: 1 year (Preferred).","в‚№8,941 - в‚№15,000 a month"
#
# 31,newElectrical Support ( Fresher),"Greater Noida, Uttar Pradesh","Job Types: Full-time, Part-time.","в‚№12,000 - в‚№16,000 a month"
#
# 32,newDistillery job,"Delhi, Delhi","Part-time hours: 48 per week.
#
# Job Types: Part-time, Regular / Permanent, Contractual / Temporary, Freelance.
#
# I want an expert personnel in the field of creatingвЂ¦","в‚№25,000 a month"
#
# 33,newFemale Hindi Online Tutor,Remote,"Teach students how to apply Grammar, how to write the hindi, explaining quality .
#
# Ability to manage time effectively.
#
# Total work: 1 year (Preferred).",в‚№200 an hour
#
# 34,newSchool Transport Escort,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Contractual / Temporary.
#
# ALSO SHALL HAVE COMPLETE KNOWLEDGE OF BUSSES AND EVERYTHING.
#
# Total work: 1 year (Preferred).","в‚№17,000 - в‚№25,217 a month"
#
# 35,newEnthusiastic Volunteers,"Temporarily Remote in New Delhi, Delhi","Job Types: Part-time, Regular / Permanent, Volunteer, Internship, Fresher.
#
# Male/ Female, Experienced/ Fresher & Students who have interest in Social Work.",NA
#
# 36,Freelance Content Writer,"Delhi, Delhi","Job Types: Full-time, Part-time, Freelance.
#
# Write clear marketing copy to promote our products/services.
#
# Identify customers needs and gaps in our content andвЂ¦","в‚№5,000 - в‚№15,000 a month"
#
# 37,OB-Gynae - Medical writer - MCQs,"Delhi, Delhi","Part-time hours: 20 per week.
#
# Team player: must be able to work as per the editor and team leadвЂ™s instructions.
#
# Questions and work must be plagiarism free.","в‚№1,66,631 - в‚№6,75,817 a year"
#
# 38,Content Writer,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Internship, Fresher.
#
# Content writing: 1 year (Preferred).","в‚№15,000 - в‚№50,000 a month"
#
# 39,Content Writer,"Meerut, Uttar Pradesh","Part-time hours: 40 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.
#
# Submit work to editors for input and approval.","в‚№5,123 - в‚№8,233 a month"
#
# 40,Social Media (Part-Time/Freelancer),"New Delhi, Delhi","Part-time hours: 5 per week.
#
# Job Types: Part-time, Contractual / Temporary, Freelance, Internship.
#
# Social media marketing: 1 year (Preferred).","в‚№7,000 - в‚№15,000 a month"
#
# 41,newCopywriter,Remote,"Job Types: Part-time, Freelance, Internship.",NA
#
# 42,newTech Product Content Writer,Remote,"Part-time hours: 35 per week.
#
# Payment will be done after every article.
#
# Need a part-time freelance English content writer for a *tech product review site*.","в‚№9,000 - в‚№15,000 a month"
#
# 43,Computer operater,"Delhi, Delhi",Computer operators *monitor and control computer and electronic data processing equipment according to standardized operating instructions*.,"в‚№12,000 a month"
#
# 44,Excel Project Developer-Contract Position,"Remote in Punjabi Bagh, Delhi, Delhi","In Spreadsheet we need to add hours with key in for each employee, studentsвЂ™ classes even when they weekly get the schedule on hourly basis and determineвЂ¦","в‚№8,000 - в‚№15,000 a week"
#
# 45,Social Media Manager,"Remote in Bengaluru, Karnataka","Part-time hours: 30 per week.
#
# Handle all social media accounts.
#
# Manage all social media interns/employees.","в‚№3,000 - в‚№5,000 a month"
#
# 46,newData Entry Operator,"Mahim, Mumbai, Maharashtra","Part-time hours: 48 per week.
#
# Pay: Up to в‚№25,000.00 per month.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Fresher.
#
# AGE LIMIT 18 TO 30 YRS.","в‚№25,000 a month"
#
# 47,Freelance & Part Time Editors,"New Delhi, Delhi",Careers Champak magazine is looking for freelance and partime editors for their book publishing division. Pls send your resume at jobseditorial@delhipressвЂ¦,NA
#
# 48,Data Entry Operator,"Temporarily Remote in Kochi, Kerala","Compiling, verifying accuracy and sorting information to prepare source data for computer entry.
#
# Entering customer and account data from source documents withinвЂ¦","в‚№9,547 - в‚№30,332 a month"
#
# 49,Freelancer Content Writer,"Gurgaon, Haryana","Job Types: Part-time, Contractual / Temporary, Freelance, Fresher.
#
# Develop grammatically flawless and informative content on different niche.","в‚№10,000 - в‚№15,000 a month"
#
# 50,newCall Center Executive,"New Delhi, Delhi","Part-time hours: 32 per week.
#
# Job Types: Full-time, Part-time, Freelance.
#
# Near Shanti palace hotel, New Delhi, Delhi: Reliably commute or planning to relocateвЂ¦","в‚№10,141 - в‚№15,000 a month"
#
# 51,Model for Jewelry and Apparel,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent.
#
# Gurgaon, Gurgaon, Haryana: Reliably commute or planning to relocate before starting work (Preferred).","в‚№8,000 - в‚№25,000 a month"
#
# 52,Internship in Content Writing,"Temporarily Remote in Delhi, Delhi","Full-time Internship which can result in pre-placement offers.
#
# Having excellent communication and presentation skills.
#
# Type: Part Time, Full Time.",NA
#
# 53,Business Associate,"Remote in Jamshedpur, Jharkhand","Part-time hours: 25 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent.
#
# Total work: 1 year (Preferred).","в‚№20,000 - в‚№50,000 a month"
#
# 54,newBUS HELPER,"Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Volunteer, Internship, Fresher.
#
# Total work: 1 year (Preferred).","в‚№9,391 - в‚№15,000 a month"
#
# 55,newDistillery job,"Delhi, Delhi","Part-time hours: 48 per week.
#
# Job Types: Part-time, Regular / Permanent, Contractual / Temporary, Freelance.
#
# I want an expert personnel in the field of creatingвЂ¦","в‚№25,000 a month"
#
# 56,Accounts Assistant,"New Delhi, Delhi+1 location","Shall have basic knowledge of accounts shall know how to operate computer very well.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.",NA
#
# 57,Content Writer (Work From Home),"Remote in Chennai, Tamil Nadu","Job Types: Full-time, Part-time, Regular / Permanent.
#
# You have to write on various niches like software, technical, home products, etc.","в‚№15,000 - в‚№20,000 a month"
#
# 58,School Administrator,"Delhi, Delhi",We are looking for School Administrator with Graduate Degree in any stream along with 2-10 years of experience in the the same or relevant profile.,"в‚№25,788 - в‚№40,000 a month"
#
# 59,Bpo telecaller,"Remote in Bengaluru, Karnataka","Part-time hours: 48 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Volunteer, Internship, Fresher.
#
# Higher Secondary(12th Pass) (Preferred).","в‚№23,000 - в‚№26,000 a month"
#
# 60,newPersonal Assistant,"Delhi, Delhi","Part-time hours: 30 per week.
#
# Must be ok with exl.
#
# Should be ok with travel in delhi ncr and pan india if required.
#
# Total work: 1 year (Preferred).","в‚№35,000 - в‚№55,000 a month"
#
# 61,Computer Operator,"New Delhi, Delhi","Job Types: Full-time, Part-time.
#
# Experience of Computers (MS Word, Excel, Power Point), Emails, Good Typing Speed.","в‚№6,000 - в‚№10,000 a month"
#
# 62,newInventory Manager,"New Delhi, Delhi","Each and every physical stock should match with our stock reflecting with software data.*.
#
# Part-time hours: 5 per week.","в‚№2,000 - в‚№8,000 a month"
#
# 63,Policy Writing Internships,"New Delhi, Delhi",Who can apply вЂ“ Students pursuing or completed degree in any stream interested in Policy research and writing policy briefs are welcome to applyвЂ¦,NA
#
# 64,Excel Project Developer-Contract Position,"Remote in Punjabi Bagh, Delhi, Delhi","In Spreadsheet we need to add hours with key in for each employee, studentsвЂ™ classes even when they weekly get the schedule on hourly basis and determineвЂ¦","в‚№8,000 - в‚№15,000 a week"
#
# 65,newAccountant cum Office Assistant,"Gurgaon, Haryana","Looking for full-time Accountant cum office assistance with a good knowledge of Tally ERP .
#
# Maintaining office equipment as needed.","в‚№12,651 - в‚№33,780 a month"
#
# 66,newMTR Milling MachineOperator,"Sonipat, Haryana","Job Types: Full-time, Part-time, Regular / Permanent.
#
# Sonipat, Haryana: Reliably commute or planning to relocate before starting work (Required).","в‚№20,000 - в‚№28,000 a month"
#
# 67,newRequired Educators,"Temporarily Remote in Jaipur, Rajasthan","Part-time hours: 24 per week.
#
# You can work from home but you must have setup for online teaching (Laptop, Pen tablet and webcam).",NA
#
# 68,General administrative tasks,"Remote in Delhi, Delhi","You have high-speed internet and a computer less than 3 years old with updated software.
#
# Per day from 8-11 am PST (you must be a person who likes to stay upвЂ¦","в‚№25,000 a month"
#
# 69,Catalogue Executives,"Gurgaon, Haryana","All positions are based out of our Gurgaon office Catalogue Executives Your job involves surfing the net, gathering knowledge, sipping a coffee andвЂ¦.. Whoa,вЂ¦",NA
#
# 70,Marketing Manager,"Remote in Noida, Uttar Pradesh","Part-time hours: 20 per week.
#
# Go the extra mile (Go above and beyond, go beyond the call of duty, go get it done on time).","в‚№10,00,000 a year"
#
# 71,Lecturer,"Delhi, Delhi","Part-time hours: 3-4 per week.
#
# Delhi, Delhi: Reliably commute or planning to relocate before starting work (Preferred).
#
# Total work: 1 year (Preferred).",в‚№400 - в‚№500 an hour
#
# 72,.Net Developer (Part Time),"Remote in Delhi, Delhi+2 locations","Job Types: Part-time, Regular / Permanent, Freelance.
#
# NET Developer for 1 year.
#
# Write clean, testable code using .
#
# Total work: 1 year (Required).","в‚№5,000 - в‚№15,000 a month"
#
# 73,Social Media Manager and Content Creator,"New Delhi, Delhi","Job Types: Full-time, Part-time.
#
# Looking for tech savvy candidates with fluency in English and Hindi to write, create and manage content for social media, blogsвЂ¦","в‚№8,000 - в‚№15,000 a month"
#
# 74,Computer Teacher,"New Delhi, Delhi",The ability to deliver Computer Science at Institute is highly desirable and should have basic and advanced computer skills and programming languages likeвЂ¦,"в‚№400 - в‚№1,000 an hour"
#
# 75,Content Writer,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Internship, Fresher.
#
# Content writing: 1 year (Preferred).","в‚№15,000 - в‚№50,000 a month"
#
# 76,Quality Analyst,"Temporarily Remote in Gurgaon, Haryana","Part-time hours: 20-25 per week.
#
# Job Types: Part-time, Freelance.
#
# Strong knowledge of unit testing, smoke testing, sanity testing,re-testing, E2E testing,вЂ¦","в‚№10,000 - в‚№15,000 a month"
#
# 77,Computer operater,"Delhi, Delhi",Computer operators *monitor and control computer and electronic data processing equipment according to standardized operating instructions*.,"в‚№12,000 a month"
#
# 78,Office Manager,"Remote in Palam Vihar, Delhi, Delhi","Part-time hours: 20-25 per week.
#
# Education: Any one, as long as the candidate is well versed with basic computer knowledge and English Language.","в‚№7,000 - в‚№10,000 a month"
#
# 79,Investigator,"Remote in Chandigarh, Chandigarh","Total work: 10 years (Preferred).
#
# Investigators (Part-time, on contractual basis)*.
#
# Involves travel within India and could be state specific.","в‚№50,000 a month"
#
# 80,newwedding video editor,"Remote in Delhi, Delhi","Part-time hours: 60 per week.
#
# Job Types: Full-time / Part-time.
#
# Job Types: Full-time, Part-time.
#
# Min. 2 years of experience.
#
# Video Editing: 2 years (Preferred).","в‚№60,000 a month"
#
# 81,newAcademic Content Writer,"Remote in Guwahati, Assam","The candidate must properly carry out their responsibilities within the organization.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Freelance,вЂ¦","в‚№7,000 - в‚№15,000 a month"
#
# 82,newAccounts Assistant,Remote,"Part-time hours: 20 per week.
#
# Job Types: Part-time, Regular / Permanent, Freelance.
#
# Looking for someone experience with bookkeeping and tax returns.","в‚№1,50,000 - в‚№2,00,000 a year"
#
# 83,Digital Designer,"Delhi, Delhi","Compensation on per design basis, regular work to be offered around 15-20 designs per month.
#
# Part-time hours: 10 per week.","в‚№4,000 - в‚№5,000 a day"
#
# 84,BUS COMPANY MANAGER / BUS TRANSPORT SUPERVISOR / SCHOOL BUS...,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent.
#
# Gurugram, Haryana: Reliably commute or planning to relocate before starting work (Required).","в‚№10,086 - в‚№20,284 a month"
#
# 85,Accounts Assistant,"Sarai Rohilla, Delhi, Delhi+1 location","Need an accounts executive who has complete knowledge of filling Gst, Esi / PF basic accounts and accounting also can work on excel completely, Should beвЂ¦","в‚№16,000 a month"
#
# 86,Academic Content Writer (Gurugram) (Work From Office),"Remote in Sohna, Haryana","Ability to research on the internet.
#
# Job Type вЂ“ Office Job (No WFH, freelancing or Part-time).
#
# Good Communication skills in English.","в‚№2,00,000 - в‚№4,00,000 a year"
#
# 87,newMarket Research Intern,"Temporarily Remote in Gurgaon, Haryana","Work on data entry.
#
# Part-time hours: 35 per week.
#
# Job Types: Full-time, Part-time, Internship.
#
# Interaction with Key Opinion Leaders.","в‚№12,000 - в‚№16,000 a month"
#
# 88,School Administrator,"Delhi, Delhi",We are looking for School Administrator with Graduate Degree in any stream along with 2-10 years of experience in the the same or relevant profile.,"в‚№25,788 - в‚№40,000 a month"
#
# 89,FACULTY FOR MANAGEMENT COURSES,"Jaipur, Rajasthan","Part-time hours: 20 per week.
#
# Job Types: Full-time, Part-time, Freelance.
#
# We are open to colleagues who have received (or are receiving) a Ph.D. in Marketing /вЂ¦","в‚№25,000 - в‚№60,000 a month"
#
# 90,newbackend,"New Delhi, Delhi","Backend office work, Must be good in using Ms Office, data entry, Computer Savy.
#
# Part time job starting from 20 June '22 - 10 July'22.",в‚№300 a day
#
# 91,newHR Executive,"Remote in Shahdara, Delhi, Delhi","Maintain employee records (attendance, EEO data etc.) according to policy and legal requirements.
#
# Salary will be between the range of 18,000-23,000 per month.","в‚№18,000 - в‚№23,000 a month"
#
# 92,newFreelance Content Writer,"Bengaluru, Karnataka","Part-time hours: 6 per week.
#
# Total work: 1 year (Required).","в‚№5,000 a month"
#
# 93,newTelecaller,"Ludhiana, Punjab","Job Types: Full-time, Part-time, Freelance, Fresher.
#
# CANDIDATE SHOULD HAVE BASIC KNOWLEDGE OF MS EXCEL and should be female.","в‚№20,000 a month"
#
# 94,newField verification executive,"Delhi, Delhi","Job Types: Part-time, Freelance.
#
# Higher Secondary(12th Pass) (Preferred).
#
# Total work: 1 year (Preferred).","в‚№9,000 - в‚№12,000 a month"
#
# 95,newCommunication consultant (Part-time),"Gurgaon, Haryana","The part-time role will require a commitment of 2 days per week up to three months.
#
# A minimum of 2+ years of work experience in communications, stakeholderвЂ¦",NA
#
# 96,General administrative tasks,"Remote in Delhi, Delhi","You have high-speed internet and a computer less than 3 years old with updated software.
#
# Per day from 8-11 am PST (you must be a person who likes to stay upвЂ¦","в‚№25,000 a month"
#
# 97,newHR Executive,"Remote in Dispur, Assam+3 locations","Part-time hours: 21-30 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Freelance.
#
# Candidates should fulfill target on time.","в‚№10,000 - в‚№12,000 a month"
#
# 98,Social Media and Marketing Intern,"Remote in Gurgaon, Haryana","Part-time hours: 10 per week.
#
# Job Types: Full-time, Part-time.
#
# Looking for a social media and marketing person to run promotions , target events for the brand,вЂ¦","в‚№8,000 - в‚№10,000 a month"
#
# 99,Math assessment developer,"Delhi, Delhi","Part-time hours: 20 per week.
#
# Job Types: Full-time, Part-time, Contractual / Temporary, Freelance, Fresher.
#
# \* Preparing Test questions for K-12 in the area ofвЂ¦","в‚№18,000 a month"
#
# 100,newGraphic Designer Intern (fresher),"New Delhi, Delhi","Part-time hours: 30 per week.
#
# Collaborate closely with our Brand Design team to translate the expression of our brand identity into our user experiences.","в‚№1,000 - в‚№2,000 a month"
#
# 101,newPart-time Nutritionist,"Green Park, Delhi, Delhi","Candidates are required to come to office 5 days a week (for 5 hours per day).
#
# Part-time hours: 30 per week.
#
# Total work: 5 years (Required).","в‚№8,000 - в‚№10,000 a month"
#
# 102,newInventory Manager,"New Delhi, Delhi","Each and every physical stock should match with our stock reflecting with software data.*.
#
# Part-time hours: 5 per week.","в‚№2,000 - в‚№8,000 a month"
#
# 103,newContent Writer's Paid Internship,"Remote in Guwahati, Assam","Part-time hours: 4-5 per week.
#
# Job Types: Part-time, Freelance, Internship, Fresher.
#
# Bonus: в‚№3000 based on quality of work after completion of three months +вЂ¦","в‚№5,500 a month"
#
# 104,newContent Writer,"Visakhapatnam, Andhra Pradesh","Candidates must have a good PC/Laptop with an internet connection.
#
# Job Types: Full-time, Part-time.
#
# Excellent interpersonal and English written skills.","в‚№12,000 - в‚№15,000 a month"
#
# 105,Business Development Officer,"Remote in Gautam Budh Nagar, Uttar Pradesh","Comfortable using a computer for various tasks.
#
# Job Types: Part-time, Contractual / Temporary.
#
# To excel in this role you should be an active listener, have aвЂ¦","в‚№80,000 - в‚№1,00,000 a month"
#
# 106,Creative Copywriter,"Gurgaon, Haryana","*Stay up to speed with relevant trends within the retail/eCommerce industry.*.
#
# Job Types: Full-time, Part-time, Freelance.
#
# Online store banners and headlines.","в‚№25,000 - в‚№40,000 a month"
#
# 107,newGraphic Designer Intern (fresher),"New Delhi, Delhi","Part-time hours: 30 per week.
#
# Collaborate closely with our Brand Design team to translate the expression of our brand identity into our user experiences.","в‚№1,000 - в‚№2,000 a month"
#
# 108,newSocial Media Graphics Designer,"Delhi, Delhi","Must have above average communication skills.
#
# Internship type: Full-time (hybrid).
#
# Part-time hours: 50 per week.
#
# Should have a flair for social media marketing.","в‚№14,000 - в‚№18,000 a month"
#
# 109,newAccountant,"Gurgaon, Haryana","Part-time hours: 60 per week.
#
# Publish financial statements in time.
#
# Hands-on experience with accounting software like TALLY.
#
# Knowledge of GST, TDS etc.","в‚№17,000 - в‚№20,000 a month"
#
# 110,Video Editor - Top 10 Style,"Delhi, Delhi","Part-time hours: 20 per week.
#
# Regular Work and Good Pay per project.
#
# We are looking for a Youtube editor who can edit top 10 style YouTube videos.","в‚№8,350 - в‚№29,097 a month"
#
# 111,Subject Matter Experts/Academic Writers,"Noida, Uttar Pradesh","This is both Full-time/Part time job opportunity depending on the convenience of the candidate.
#
# Digiversal is looking for full time writers/researchers to workвЂ¦",NA
#
# 112,newNeed Tutors,"Lucknow, Uttar Pradesh","Part-time hours: 36 per week.
#
# Job Types: Part-time, Freelance, Fresher.
#
# Lucknow, Uttar Pradesh: Reliably commute or planning to relocate before starting work вЂ¦","в‚№6,000 - в‚№20,000 a month"
#
# 113,newTeam Member,"Noida, Uttar Pradesh+5 locations","*Performs order processing вЂ“ Process the recipes accurately as per the process in a fast and timely manner.
#
# 10*. Ensures fast and timely service to customers,вЂ¦","в‚№13,000 - в‚№15,000 a month"
#
# 114,newBusiness Development Intern,"Noida, Uttar Pradesh","Job Types: Full-time, Part-time, Internship.
#
# Job Types*: Full-time, Part-time, Internship, Fresher.
#
# Learns and becomes proficient on internal software systems.",NA
#
# 115,newEsi And Pf Consultant,"Greater Noida, Uttar Pradesh","Part-time hours: 20 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Internship, Fresher.","в‚№8,000 - в‚№20,000 a month"
#
# 116,newDistrict Manager,"Remote in Dhanbad, Jharkhand","Part-time hours: 21 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Fresher.
#
# Dhanbad, Dhanbad - 826001, Jharkhand: Reliably commute or planningвЂ¦","в‚№20,000 a month"
#
# 117,newArticle Writer,"Remote in Jammu, Jammu and Kashmir",I recently started this word and I need hardworking and trustworthy people who know the knowledge of how to type and post an article regarding news with noвЂ¦,NA
#
# 118,Business Development (Part-time WFH),Remote,"Be available for minimum of 4 hours per day.
#
# Part-time hours: 4 per week.
#
# Maintain call records and follow up as per schedule.","в‚№10,000 a month"
#
# 119,newFinance Assistant,"Remote in Bengaluru, Karnataka",We are Hiring for Leader's who have good experience in Banking and Any Financial sector any apply and also having very good customer contact .,"в‚№30,000 - в‚№50,000 a month"
#
# 120,newOnline Marketing Executive,"New Delhi, Delhi","Job Types: Full-time, Part-time.
#
# We are looking for Good & Experienced Candidate proficient in online selling on various ecommerce websites like Amazon,вЂ¦","в‚№9,988 - в‚№37,669 a month"
#
# 121,Content Writer,+1 locationRemote,"Part-time hours: 45 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Volunteer, Internship, Fresher.","в‚№3,000 a month"
#
# 122,Real Estate Agent,"Delhi, Delhi","All candidates must be vaccinated and use facemask and maintain social distance on daily basis.
#
# Job Types: Full-time, Part-time, Freelance, Fresher.","в‚№20,000 a month"
#
# 123,Content Writer Intern,"New Delhi, Delhi","Job Types: Part-time, Internship.
#
# Prepare blogs for the website.
#
# Prepare content for email campaigns.
#
# Co-ordinate with the marketing team for the content.","в‚№1,000 a month"
#
# 124,Subject Matter Expert,"Delhi, Delhi","Prefer candidates with Math Background(Undergrads can also apply).
#
# Job Types: Part-time, Contractual / Temporary, Freelance, Fresher.","в‚№18,000 a month"
#
# 125,newCashier/Sales Assistant,"Delhi, Delhi","Job Types: Full-time, Part-time.
#
# Yes vivid protocols are followed.
#
# Delhi, Delhi - 110051, Delhi: Reliably commute or planning to relocate before starting work вЂ¦","в‚№12,000 - в‚№15,000 a month"
#
# 126,Marketing Manager,"Remote in Noida, Uttar Pradesh","Part-time hours: 20 per week.
#
# Go the extra mile (Go above and beyond, go beyond the call of duty, go get it done on time).","в‚№10,00,000 a year"
#
# 127,newData Entry Work,"New Alipore, Kolkata, West Bengal","Job Types: Full-time, Part-time.
#
# Higher Secondary(12th Pass) (Preferred).","в‚№8,000 - в‚№9,000 a month"
#
# 128,Fresh Faces For Instagram Profile Collaboration,"Delhi, Delhi","Part-time hours: 35 per week.
#
# Modeling & Styling For The Ethnic Garment Shoots On 30% Collaboration From Scratch.
#
# Modeling For New Creative Videos/Reels.","в‚№2,000 a month"
#
# 129,Freelance Content Writer,"Remote in Faridabad, Haryana","Part-time hours: 28 per week.
#
# Job Types: Part-time, Freelance, Internship.
#
# The work will be contract based (Avg Monthly income will be 30-15k), more.","в‚№15,000 a month"
#
# 130,Academic Content Writer (Gurugram) (Work From Office),"Remote in Sohna, Haryana","Ability to research on the internet.
#
# Job Type вЂ“ Office Job (No WFH, freelancing or Part-time).
#
# Good Communication skills in English.","в‚№2,00,000 - в‚№4,00,000 a year"
#
# 131,HR and Operation Head Intern,Remote,"Generate reports and data of the team.
#
# Job Types: Full-time, Part-time, Internship, Fresher.
#
# Ensure that the project is delivered on time, within scope, andвЂ¦",NA
#
# 132,newBusiness Development Executive (BDE),"Remote in Noida, Uttar Pradesh","Good communication skills (English or Hindi both will work).
#
# Training sessions that will be provided by us and 35 account is minimum target,.","в‚№10,000 a month"
#
# 133,Content Writer,"New Delhi, Delhi","Part-time hours: 40 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Freelance, Volunteer, Internship, Fresher.
#
# Total work: 1 year (Preferred).","в‚№9,000 - в‚№15,000 a month"
#
# 134,newData Entry Operator,"Sahar, Mumbai, Maharashtra","Part-time hours: 48 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Fresher.
#
# AGE LIMIT 18 TO 30 YRS.
#
# Microsoft Office: 1 year (Preferred).","в‚№24,000 a month"
#
# 135,Freelance & Part Time Editors,"New Delhi, Delhi",Careers Champak magazine is looking for freelance and partime editors for their book publishing division. Pls send your resume at jobseditorial@delhipressвЂ¦,NA
#
# 136,BLOOD BANK OFFICER/INCHARGE (PART TIME),"New Delhi, Delhi","Job Code : DHLI/HR/18/05/2022 No of Position : 01 Job Description MBBS, MD(Pathology) with min 4-5 yrs exp as Blood Bank Officer/Incharge in NABHвЂ¦",NA
#
# 137,newEvent Planner,"Gurgaon, Haryana","Part-time hours: 40 per week.
#
# Plan and organize events with attention to financial and time constraints.
#
# Job Types: Full-time, Part-time, Regular / Permanent,вЂ¦","в‚№15,000 a month"
#
# 138,newVideo Editor,"Remote in Delhi, Delhi","Part-time hours: 30 per week.
#
# Job Types: Part-time, Regular / Permanent, Contractual / Temporary.
#
# Strong time management, organization, problem-solving, andвЂ¦","в‚№9,000 a month"
#
# 139,newMobilizer,"Remote in Alwar, Rajasthan","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Internship, Fresher.
#
# Data collection and Call to students.","в‚№8,000 - в‚№15,000 a month"
#
# 140,newSchool Transport Supervisor,"Gurgaon, Haryana","Job Types: Full-time, Part-time.
#
# Manage school busses, Driver/ Helper/ Other Busses.
#
# Gurugram, Gurugram - 122006, Haryana: Reliably commute or planning toвЂ¦","в‚№23,000 a month"
#
# 141,Sales Assistant,"Remote in Delhi, Delhi","Part-time hours: 4 per week.
#
# 7000/- as stipend and companyвЂ™s training certificate, on successfully selling life insurance policy with minimum premium of Rs.","в‚№7,000 - в‚№20,000 a month"
#
# 142,Gym Receptionist,"Delhi, Delhi",The candidate must know about the basic computer and know a bit about excel e.g familiar with the data entries.,"в‚№10,000 - в‚№12,000 a month"
#
# 143,newHR Recruiter,"Noida, Uttar Pradesh","Part-time hours: 4 per week.
#
# This role is for part time from Noida office.
#
# Responsible for achieving a good conversion ratio of submitting into interview andвЂ¦","в‚№8,086 - в‚№20,000 a month"
#
# 144,newEsi And Pf Consultant,"Greater Noida, Uttar Pradesh","Part-time hours: 20 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Internship, Fresher.","в‚№8,000 - в‚№20,000 a month"
#
# 145,newTelesales,"Kailash, Delhi+1 location","Part-time hours: 54 per week.
#
# Job Types: Full-time, Part-time, Freelance, Fresher.
#
# Higher Secondary(12th Pass) (Preferred).
#
# Total work: 1 year (Required).","в‚№8,000 - в‚№25,000 a month"
#
# 146,newHR Executive,"Delhi, Delhi","Job Types: Full-time, Part-time.
#
# Yes vivid protocols are followed.
#
# Delhi, Delhi, Delhi: Reliably commute or planning to relocate before starting work (PreferredвЂ¦","в‚№15,000 - в‚№25,000 a month"
#
# 147,Part Time Calling profile,"Delhi, Delhi","Part-time hours: 30 per week.
#
# Those who are looking for part time work.
#
# Okhla, Delhi, Delhi, Delhi - 110020, Delhi: Reliably commute or planning to relocateвЂ¦","в‚№8,000 - в‚№10,000 a month"
#
# 148,newPHP Developer,Remote,"Duration: * Long Term (minimum 1 year).
#
# Job Types: Full-time, Part-time.
#
# Domain: * Digital Marketing for US Colleges.
#
# PHP Developing: 5 years (Preferred).","в‚№8,00,000 - в‚№13,00,000 a year"
#
# 149,Content Writer,"Remote in Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Internship.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.",NA
#
# 150,Transport Supervisor,"Mayur Vihar, Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent.
#
# E п‚· Oversee purchases of repair parts and department supplies.
#
# Total work: 1 year (Preferred).","в‚№19,867 - в‚№20,034 a month"
#
# 151,newVideo Editor,"Chandigarh, Chandigarh","Part-time hours: 25 per week.
#
# Higher Secondary(12th Pass) (Preferred).
#
# Video Editing: 1 year (Preferred).
#
# Total work: 1 year (Preferred).","в‚№10,019 - в‚№20,000 a month"
#
# 152,Computer Teacher,"Laxmi Nagar, Delhi, Delhi","We are looking for a computer trainer who has a good command of adv excel basic computer Tally.
#
# Job Types: Full-time, Part-time.
#
# Total work: 1 year (Preferred).","в‚№12,000 - в‚№18,000 a month"
#
# 153,newSocial Media Executive,"Greater Kailash II, Delhi, Delhi","Job Types: Full-time, Part-time.
#
# Social media marketing: 1 year (Preferred).
#
# Total work: 1 year (Preferred).","в‚№20,000 - в‚№30,000 a month"
#
# 154,newHuman Resources Internship,"New Delhi, Delhi","Part-time hours: 30 per week.
#
# Available immediately to start with the internship position.
#
# Helping the organization expand their reach.","в‚№1,000 - в‚№2,000 a month"
#
# 155,Telecaller,"Connaught Place, Delhi, Delhi","Part-time hours: 30 per week.
#
# Updating feedback on excel sheet.
#
# Good communication skills required ( English).
#
# Calling required from 12noon to 5pm.","в‚№8,000 a month"
#
# 156,Social Media Manager,"New Delhi, Delhi","Keep pace with social media and internet marketing industry trends and developments.
#
# Part-time hours: 40 per week.
#
# Social Media Occupations: 1 year (Preferred).",NA
#
# 157,Sales Manager,"New Delhi, Delhi","Part-time hours: 45 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Internship.
#
# Sharp Eye Infotech is Looking for the Sales and MarketingвЂ¦","в‚№1,38,536 - в‚№6,69,016 a year"
#
# 158,newContent Writer,"Green Park, Delhi, Delhi","Part-time hours: 20 per week.
#
# It can be home based job or full time office job.
#
# Job Types: Full-time, Part-time, Freelance.
#
# Content writing: 1 year (Preferred).","в‚№12,000 - в‚№15,000 a month"
#
# 159,Warehouse Assistant,"Tihar, Delhi","Part-time hours: 4 per week.
#
# We have urgent requirement for warehouse Worker both male & Female for Part Time as well as Full Time.","в‚№5,000 a month"
#
# 160,Human Resources Executive,"Remote in Delhi, Delhi","Searching for the right candidate as per the client requirement through various job portal.
#
# Sourcing as per the requisitions for various departments and furtherвЂ¦",NA
#
# 161,newHR Internship,"Remote in Mumbai, Maharashtra","Part-time hours: 25 per week.
#
# Pay: в‚№5,000.00 per month.
#
# Job Types: Part-time, Internship, Fresher.
#
# Documentation & Negotiation Maintain Daily tracker .","в‚№5,000 a month"
#
# 162,Website Manager,"Remote in Delhi, Delhi","Part-time hours: 20 per week.
#
# Turn raw data into actionable insights (funnel conversion, campaigns, A/B tests, website behavior, customer journey experiments).","в‚№40,000 - в‚№75,000 a month"
#
# 163,feild executive,"New Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Fresher.
#
# Job Type : - Full Time & Part Time.","в‚№12,000 - в‚№15,000 a month"
#
# 164,Creative,India,"Both full-time and part-time jobs are available.
#
# By adjusting your teaching style to each userвЂ™s individual skill level, you maximise his or her understandingвЂ¦",NA
#
# 165,newPHP Developer,Remote,"Duration: * Long Term (minimum 1 year).
#
# Job Types: Full-time, Part-time.
#
# Domain: * Digital Marketing for US Colleges.
#
# PHP Developing: 5 years (Preferred).","в‚№8,00,000 - в‚№13,00,000 a year"
#
# 166,Content Writer,"Remote in Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Internship.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.",NA
#
# 167,newInterior Designer,"Delhi, Delhi","Part-time hours: 20 per week.
#
# WeвЂ™re looking for a candidate who can join us with zeal to learn something in a new prospect.
#
# Total work: 2 years (Required).","в‚№25,000 a month"
#
# 168,Freelancer Content Writer,"Gurgaon, Haryana","Job Types: Part-time, Contractual / Temporary, Freelance, Fresher.
#
# Develop grammatically flawless and informative content on different niche.","в‚№10,000 - в‚№15,000 a month"
#
# 169,newPower BI Developer,Remote,"This will be a contractual role, the candidate must possess at least 2 years of experience, creating and developing Dashboards in Power BI by connecting to aвЂ¦","в‚№1,000 - в‚№3,000 a day"
#
# 170,Business Development Officer,"Remote in Gautam Budh Nagar, Uttar Pradesh","Comfortable using a computer for various tasks.
#
# Job Types: Part-time, Contractual / Temporary.
#
# To excel in this role you should be an active listener, have aвЂ¦","в‚№80,000 - в‚№1,00,000 a month"
#
# 171,newSEO Executive,"Roorkee, Uttarakhand","Weekly tasks will be provided to deliver in the respective time span.
#
# Job Types: Full-time, Regular / Permanent, Fresher.
#
# Total work: 1 year (Preferred).","в‚№15,500 - в‚№25,500 a month"
#
# 172,newClient Servicing Executive,"Gurgaon, Haryana","Part-time hours: 40 per week.
#
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.
#
# Inspiring repeat business from clients.","в‚№15,000 a month"
#
# 173,newContent Writer,"Remote in Bengaluru, Karnataka","Attitude and passion to come up with fresh and innovative ideas for great and interesting content.
#
# Employment Type: Full Time/Part Time.","в‚№3,00,000 - в‚№6,00,000 a year"
#
# 174,Tender Executive,"Ashok Vihar, Delhi, Delhi","Job Types: Full-time, Part-time.
#
# Ashok Vihar, Delhi - 110052, Delhi: Reliably commute or planning to relocate before starting work (Preferred).","в‚№20,000 - в‚№25,000 a month"
#
# 175,newHuman Resources Internship,"New Delhi, Delhi","Part-time hours: 30 per week.
#
# Available immediately to start with the internship position.
#
# Helping the organization expand their reach.","в‚№1,000 - в‚№2,000 a month"
#
# 176,Digital Marketing Intern,"Dwarka, Delhi, Delhi","Job Types: Full-time, Part-time, Internship.
#
# We are hiring interim candidate also who passed out and have any diploma in digital marketing.","в‚№9,000 - в‚№22,000 a month"
#
# 177,Marketing Intern,+1 locationRemote,"Part-time hours: 25-30 per week.
#
# Stipend : в‚№2500-10000 /- For Showdoctors.com ( Depends on joining type).
#
# Encourage Medical Equipment Suppliers/ Doctors to beвЂ¦","в‚№10,000 a month"
#
# 178,newCustomer Support Executive cum Telecalling,"Chennai, Tamil Nadu","Job Types: Part-time, Regular / Permanent, Fresher.
#
# The primary job of a *Customer Support Executive* is to *address customer issues and resolve them in aвЂ¦","в‚№25,000 - в‚№35,000 a month"
#
# 179,newCompetitive Programming with C++,Remote,"Job Types: Part-time, Contractual / Temporary, Freelance.
#
# Required Competitive Programming with C++ Trainer who is expert in topics with Problem Solving skills:вЂ¦",в‚№500 - в‚№800 an hour

# %%
import csv

with open('job.csv', newline='') as csvfile:
    txt = csv.reader(csvfile, delimiter=' ')
    for i in txt:
        print(i)
    f.close()
# Out:
# [',title,location,summary,salary']
# ['0,Customer', 'Care', 'Proffessional', '(Voice),"Gurgaon,', 'Haryana","MS', 'office', 'suites', 'such', 'as', 'Excel,', 'Word,', 'PowerPoint.']
# ['Enhance', 'our', 'customersвЂ™', 'experience', 'by', 'finding', 'opportunities', 'to', 'offer', 'products', 'based', 'on', 'our', 'CardmembersвЂ™', 'needs.","в‚№5,00,000', '-', 'в‚№9,50,000', 'a', 'year"']
# ['1,newFreelance', 'Writer', '-', 'Work', 'from', 'Home,"Remote', 'in', 'Delhi,', 'Delhi","Submit', 'a', 'minimum', 'of', '5', 'articles', '(an', 'average', 'of', '1,000', 'words', 'each)', 'per', 'month.']
# ['Produce', 'a', 'minimum', 'of', '5', 'articles', 'per', 'month.']
# ['Experience', 'in', 'writing', 'travel', 'content.","в‚№4,000', '-', 'в‚№15,000', 'a', 'month"']
# ['2,Online', 'Maths/Science', 'Tutor', 'for', 'grades(1-7),Remote,"Taking', 'a', 'minimum', 'of', '3', 'Lectures', 'in', 'a', 'day', '(Can', 'take', 'more', 'if', 'time', 'permits)', 'and', 'a', 'minimum', 'of', '6', 'days', 'working', '(including', 'weekends.']
# ['Preferred', 'timings', '2', 'PM', 'to', '8', 'PM.",в‚№225', '-', 'в‚№350', 'an', 'hour']
# ['3,Computer', 'Operator,"New', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Experience', 'of', 'Computers', '(MS', 'Word,', 'Excel,', 'Power', 'Point),', 'Emails,', 'Good', 'Typing', 'Speed.","в‚№6,000', '-', 'в‚№10,000', 'a', 'month"']
# ['4,newFresher', 'Hiring', 'for', 'documents', 'verification', 'process,"Malviya', 'Nagar,', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.']
# ['Attend', 'calls', '&', 'revert', 'to', 'E-mails', 'professionally', 'to', 'provide', 'information', 'about', 'products', 'and', 'services,', 'obtainвЂ¦","в‚№18,667', '-', 'в‚№34,655', 'a', 'month"']
# ['5,Computer', 'operater,"Delhi,', 'Delhi",Computer', 'operators', '*monitor', 'and', 'control', 'computer', 'and', 'electronic', 'data', 'processing', 'equipment', 'according', 'to', 'standardized', 'operating', 'instructions*.,"в‚№12,000', 'a', 'month"']
# ['6,newSpa', 'Therapist,"Delhi,', 'Delhi+1', 'location","Part-time', 'hours:', '15', 'per', 'week.']
# ['Candidate', 'should', 'possess', 'good', 'communication', 'skill,', 'must', 'be', 'hard', 'working', 'and', 'flexible.']
# ['Job', 'Types:', 'Full-time,', 'Part-time.","в‚№52,000', '-', 'в‚№55,000', 'a', 'month"']
# ['7,Data', 'Entry', 'Operator,"Lucknow,', 'Uttar', 'Pradesh","Knowledge', 'Of', 'computer', 'is', 'a', 'must.']
# ['Main', 'work', 'is,', 'Data', 'entry', 'of', 'Documents', 'and', 'Catalogues', 'on', 'the', 'company', 'server.']
# ['Zero', 'Experience', 'Candidates', 'can', 'also', 'apply.",в‚№25', '-', 'в‚№70', 'an', 'hour']
# ['8,Freelance', 'Content', 'Writer,"Gurgaon,', 'Haryana","Gurugram,', 'Haryana:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', '(Required).']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№9,372', '-', 'в‚№40,473', 'a', 'month"']
# ['9,Excel', 'Project', 'Developer-Contract', 'Position,"Remote', 'in', 'Punjabi', 'Bagh,', 'Delhi,', 'Delhi","In', 'Spreadsheet', 'we', 'need', 'to', 'add', 'hours', 'with', 'key', 'in', 'for', 'each', 'employee,', 'studentsвЂ™', 'classes', 'even', 'when', 'they', 'weekly', 'get', 'the', 'schedule', 'on', 'hourly', 'basis', 'and', 'determineвЂ¦","в‚№8,000', '-', 'в‚№15,000', 'a', 'week"']
# ['10,Urgent', 'Requirement', 'of', 'Telecaller,"Tilak', 'Nagar,', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Volunteer,', 'Internship,', 'Fresher.","в‚№15,000', '-', 'в‚№50,000', 'a', 'month"']
# ['11,newWeb', 'Content', 'Writer,"Noida,', 'Uttar', 'Pradesh","Every', 'website', 'has', 'a', 'specific', 'target', 'audience', 'and', 'requires', 'the', 'most', 'relevant', 'content', 'to', 'attract', 'business.']
# ['We', 'are', 'looking', 'to', 'hire', 'a', 'A', 'Website', 'content', 'writer', 'orвЂ¦",в‚№8.56', '-', 'в‚№20.00', 'an', 'hour']
# ['12,Academic', 'Writer', '(Freelance),"Remote', 'in', 'Noida,', 'Uttar', 'Pradesh","The', 'candidates', 'must', 'have', 'good', 'typing', 'speed,', 'the', 'ability', 'to', 'write', 'good', 'quality', 'content', 'in', 'English,', 'the', 'ability', 'to', 'do', 'intensive', 'research,', 'a', 'good', 'understanding', 'ofвЂ¦","в‚№10,000', '-', 'в‚№20,000', 'a', 'month"']
# ['13,Data', 'Entry', 'Operator,"Darbhanga,', 'Bihar","Required', 'data', 'entry', 'operator', 'with', 'minimum', 'speed', '40.']
# ['Part-time', 'hours:', '48', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Contractual', '/', 'Temporary,', 'Freelance.","в‚№10,000', 'a', 'month"']
# ['14,Content', 'Writer,"Remote', 'in', 'Delhi,', 'Delhi","Part-time', 'hours:', '56', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.","в‚№21,000', 'a', 'month"']
# ['15,newHR', 'Recruiter,"Remote', 'in', 'Delhi,', 'Delhi","Means', 'he', 'must', 'be', 'told', 'how', 'to', 'do', 'the', 'establishment', 'of', 'communication', 'and', 'achieve', 'the', 'desired', 'outcome.']
# ['Part-time', 'hours:', '15', 'per', 'week.",NA']
# ['16,newFront', 'Desk', 'Receptionist,"Ghaziabad,', 'Uttar', 'Pradesh","Part-time', 'hours:', '25', 'per', 'week.']
# ['Keep', 'track', 'of', 'office', 'supplies', 'and', 'place', 'orders', 'when', 'required.']
# ['Job', 'Types:', 'Part-time,', 'Regular', '/', 'Permanent,', 'Fresher.","в‚№8,086', '-', 'в‚№10,000', 'a', 'month"']
# ['17,newCall', 'Center', 'Executive,"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '32', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance.']
# ['Near', 'Shanti', 'palace', 'hotel,', 'New', 'Delhi,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocateвЂ¦","в‚№10,141', '-', 'в‚№15,000', 'a', 'month"']
# ['18,Human', 'Resources', 'Internship,"Temporarily', 'Remote', 'in', 'Delhi,', 'Delhi+2', 'locations","All', 'students', 'pursuing', 'under', 'graduate', 'degree/post', 'graduate', 'degree.']
# ['Any', 'graduate,', 'digital', 'marketing,', 'social', 'media', 'marketing,', 'email', 'marketing.","в‚№6,000', '-', 'в‚№9,000', 'a', 'month"']
# ['19,newQuality', 'Analyst,"Chandigarh,', 'Chandigarh","Analyse', 'and', 'verify', 'customer', 'accounts', 'as', 'per', 'available', 'data.']
# ['Any', 'Graduate', 'or', 'under-graduate', 'with', 'minimum', '1', 'year', 'of', 'experience.","в‚№3,50,000', 'a', 'month"']
# ['20,newCashier/Sales', 'Assistant,"Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Yes', 'vivid', 'protocols', 'are', 'followed.']
# ['Delhi,', 'Delhi', '-', '110051,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', 'вЂ¦","в‚№12,000', '-', 'в‚№15,000', 'a', 'month"']
# ['21,Social', 'Media', '(Part-Time/Freelancer),"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '5', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Internship.']
# ['Social', 'media', 'marketing:', '1', 'year', '(Preferred).","в‚№7,000', '-', 'в‚№15,000', 'a', 'month"']
# ['22,newHR', 'Intern,"Remote', 'in', 'Noida,', 'Uttar', 'Pradesh","Attending', 'all', 'meeting', 'on', 'time.']
# ['Job', 'Types:', 'Part-time,', 'Internship,', 'Fresher.']
# ['Arranging', 'Session', 'and', 'problem', 'solving.']
# ['Opening', '(', '2', 'in', '1', ')', 'Account', 'in', 'yes', 'Bank.","в‚№7,000', 'a', 'month"']
# ['23,newBUS', 'HELPER,"Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Volunteer,', 'Internship,', 'Fresher.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№9,391', '-', 'в‚№15,000', 'a', 'month"']
# ['24,newComputer', 'Teacher', 'Required,"Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Fresher.']
# ['Total', 'work:', '1', 'year', '(Preferred).",NA']
# ['25,newComputer', 'Operator,"Delhi,', 'Delhi","Data', 'entry:', '1', 'year', '(Preferred).']
# ['Part-time', 'hours:', '40', 'per', 'week.']
# ['Higher', 'Secondary(12th', 'Pass)', '(Required).']
# ['Delhi,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocateвЂ¦","в‚№8,000', '-', 'в‚№20,000', 'a', 'month"']
# ['26,Model', 'for', 'Jewelry', 'and', 'Apparel,"Gurgaon,', 'Haryana","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.']
# ['Gurgaon,', 'Gurgaon,', 'Haryana:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', '(Preferred).","в‚№8,000', '-', 'в‚№25,000', 'a', 'month"']
# ['27,newNews', 'Reporter,"Ghaziabad,', 'Uttar', 'Pradesh","Skills', 'needed', 'for', 'the', 'job', '-', 'English', 'and', 'Hindi', 'typing,', 'good', 'vocabulary', 'in', 'any', 'of', 'the', 'languages.']
# ['Part-time', 'hours:', '72', 'per', 'week.']
# ['Total', 'work:', '10', 'years', '(Preferred).","в‚№5,000', '-', 'в‚№15,000', 'a', 'month"']
# ['28,newFemale', 'Hindi', 'Online', 'Tutor,Remote,"Teach', 'students', 'how', 'to', 'apply', 'Grammar,', 'how', 'to', 'write', 'the', 'hindi,', 'explaining', 'quality', '.']
# ['Ability', 'to', 'manage', 'time', 'effectively.']
# ['Total', 'work:', '1', 'year', '(Preferred).",в‚№200', 'an', 'hour']
# ['29,newComputer', 'Teacher,"Remote', 'in', 'Ranchi,', 'Jharkhand",Part-time', 'hours:', '14', 'per', 'week.,"в‚№20,000', 'a', 'month"']
# ['30,Content', 'Writer-', 'Web,"Jaipur,', 'Rajasthan","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Freelance,', 'Internship,', 'Fresher.']
# ['Copy-editing', 'and', 'proof', 'reading', 'articles.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№8,941', '-', 'в‚№15,000', 'a', 'month"']
# ['31,newElectrical', 'Support', '(', 'Fresher),"Greater', 'Noida,', 'Uttar', 'Pradesh","Job', 'Types:', 'Full-time,', 'Part-time.","в‚№12,000', '-', 'в‚№16,000', 'a', 'month"']
# ['32,newDistillery', 'job,"Delhi,', 'Delhi","Part-time', 'hours:', '48', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance.']
# ['I', 'want', 'an', 'expert', 'personnel', 'in', 'the', 'field', 'of', 'creatingвЂ¦","в‚№25,000', 'a', 'month"']
# ['33,newFemale', 'Hindi', 'Online', 'Tutor,Remote,"Teach', 'students', 'how', 'to', 'apply', 'Grammar,', 'how', 'to', 'write', 'the', 'hindi,', 'explaining', 'quality', '.']
# ['Ability', 'to', 'manage', 'time', 'effectively.']
# ['Total', 'work:', '1', 'year', '(Preferred).",в‚№200', 'an', 'hour']
# ['34,newSchool', 'Transport', 'Escort,"Gurgaon,', 'Haryana","Job', 'Types:', 'Full-time,', 'Part-time,', 'Contractual', '/', 'Temporary.']
# ['ALSO', 'SHALL', 'HAVE', 'COMPLETE', 'KNOWLEDGE', 'OF', 'BUSSES', 'AND', 'EVERYTHING.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№17,000', '-', 'в‚№25,217', 'a', 'month"']
# ['35,newEnthusiastic', 'Volunteers,"Temporarily', 'Remote', 'in', 'New', 'Delhi,', 'Delhi","Job', 'Types:', 'Part-time,', 'Regular', '/', 'Permanent,', 'Volunteer,', 'Internship,', 'Fresher.']
# ['Male/', 'Female,', 'Experienced/', 'Fresher', '&', 'Students', 'who', 'have', 'interest', 'in', 'Social', 'Work.",NA']
# ['36,Freelance', 'Content', 'Writer,"Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance.']
# ['Write', 'clear', 'marketing', 'copy', 'to', 'promote', 'our', 'products/services.']
# ['Identify', 'customers', 'needs', 'and', 'gaps', 'in', 'our', 'content', 'andвЂ¦","в‚№5,000', '-', 'в‚№15,000', 'a', 'month"']
# ['37,OB-Gynae', '-', 'Medical', 'writer', '-', 'MCQs,"Delhi,', 'Delhi","Part-time', 'hours:', '20', 'per', 'week.']
# ['Team', 'player:', 'must', 'be', 'able', 'to', 'work', 'as', 'per', 'the', 'editor', 'and', 'team', 'leadвЂ™s', 'instructions.']
# ['Questions', 'and', 'work', 'must', 'be', 'plagiarism', 'free.","в‚№1,66,631', '-', 'в‚№6,75,817', 'a', 'year"']
# ['38,Content', 'Writer,"Gurgaon,', 'Haryana","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Internship,', 'Fresher.']
# ['Content', 'writing:', '1', 'year', '(Preferred).","в‚№15,000', '-', 'в‚№50,000', 'a', 'month"']
# ['39,Content', 'Writer,"Meerut,', 'Uttar', 'Pradesh","Part-time', 'hours:', '40', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Internship,', 'Fresher.']
# ['Submit', 'work', 'to', 'editors', 'for', 'input', 'and', 'approval.","в‚№5,123', '-', 'в‚№8,233', 'a', 'month"']
# ['40,Social', 'Media', '(Part-Time/Freelancer),"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '5', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Internship.']
# ['Social', 'media', 'marketing:', '1', 'year', '(Preferred).","в‚№7,000', '-', 'в‚№15,000', 'a', 'month"']
# ['41,newCopywriter,Remote,"Job', 'Types:', 'Part-time,', 'Freelance,', 'Internship.",NA']
# ['42,newTech', 'Product', 'Content', 'Writer,Remote,"Part-time', 'hours:', '35', 'per', 'week.']
# ['Payment', 'will', 'be', 'done', 'after', 'every', 'article.']
# ['Need', 'a', 'part-time', 'freelance', 'English', 'content', 'writer', 'for', 'a', '*tech', 'product', 'review', 'site*.","в‚№9,000', '-', 'в‚№15,000', 'a', 'month"']
# ['43,Computer', 'operater,"Delhi,', 'Delhi",Computer', 'operators', '*monitor', 'and', 'control', 'computer', 'and', 'electronic', 'data', 'processing', 'equipment', 'according', 'to', 'standardized', 'operating', 'instructions*.,"в‚№12,000', 'a', 'month"']
# ['44,Excel', 'Project', 'Developer-Contract', 'Position,"Remote', 'in', 'Punjabi', 'Bagh,', 'Delhi,', 'Delhi","In', 'Spreadsheet', 'we', 'need', 'to', 'add', 'hours', 'with', 'key', 'in', 'for', 'each', 'employee,', 'studentsвЂ™', 'classes', 'even', 'when', 'they', 'weekly', 'get', 'the', 'schedule', 'on', 'hourly', 'basis', 'and', 'determineвЂ¦","в‚№8,000', '-', 'в‚№15,000', 'a', 'week"']
# ['45,Social', 'Media', 'Manager,"Remote', 'in', 'Bengaluru,', 'Karnataka","Part-time', 'hours:', '30', 'per', 'week.']
# ['Handle', 'all', 'social', 'media', 'accounts.']
# ['Manage', 'all', 'social', 'media', 'interns/employees.","в‚№3,000', '-', 'в‚№5,000', 'a', 'month"']
# ['46,newData', 'Entry', 'Operator,"Mahim,', 'Mumbai,', 'Maharashtra","Part-time', 'hours:', '48', 'per', 'week.']
# ['Pay:', 'Up', 'to', 'в‚№25,000.00', 'per', 'month.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Fresher.']
# ['AGE', 'LIMIT', '18', 'TO', '30', 'YRS.","в‚№25,000', 'a', 'month"']
# ['47,Freelance', '&', 'Part', 'Time', 'Editors,"New', 'Delhi,', 'Delhi",Careers', 'Champak', 'magazine', 'is', 'looking', 'for', 'freelance', 'and', 'partime', 'editors', 'for', 'their', 'book', 'publishing', 'division.', 'Pls', 'send', 'your', 'resume', 'at', 'jobseditorial@delhipressвЂ¦,NA']
# ['48,Data', 'Entry', 'Operator,"Temporarily', 'Remote', 'in', 'Kochi,', 'Kerala","Compiling,', 'verifying', 'accuracy', 'and', 'sorting', 'information', 'to', 'prepare', 'source', 'data', 'for', 'computer', 'entry.']
# ['Entering', 'customer', 'and', 'account', 'data', 'from', 'source', 'documents', 'withinвЂ¦","в‚№9,547', '-', 'в‚№30,332', 'a', 'month"']
# ['49,Freelancer', 'Content', 'Writer,"Gurgaon,', 'Haryana","Job', 'Types:', 'Part-time,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Fresher.']
# ['Develop', 'grammatically', 'flawless', 'and', 'informative', 'content', 'on', 'different', 'niche.","в‚№10,000', '-', 'в‚№15,000', 'a', 'month"']
# ['50,newCall', 'Center', 'Executive,"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '32', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance.']
# ['Near', 'Shanti', 'palace', 'hotel,', 'New', 'Delhi,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocateвЂ¦","в‚№10,141', '-', 'в‚№15,000', 'a', 'month"']
# ['51,Model', 'for', 'Jewelry', 'and', 'Apparel,"Gurgaon,', 'Haryana","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.']
# ['Gurgaon,', 'Gurgaon,', 'Haryana:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', '(Preferred).","в‚№8,000', '-', 'в‚№25,000', 'a', 'month"']
# ['52,Internship', 'in', 'Content', 'Writing,"Temporarily', 'Remote', 'in', 'Delhi,', 'Delhi","Full-time', 'Internship', 'which', 'can', 'result', 'in', 'pre-placement', 'offers.']
# ['Having', 'excellent', 'communication', 'and', 'presentation', 'skills.']
# ['Type:', 'Part', 'Time,', 'Full', 'Time.",NA']
# ['53,Business', 'Associate,"Remote', 'in', 'Jamshedpur,', 'Jharkhand","Part-time', 'hours:', '25', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№20,000', '-', 'в‚№50,000', 'a', 'month"']
# ['54,newBUS', 'HELPER,"Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Volunteer,', 'Internship,', 'Fresher.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№9,391', '-', 'в‚№15,000', 'a', 'month"']
# ['55,newDistillery', 'job,"Delhi,', 'Delhi","Part-time', 'hours:', '48', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance.']
# ['I', 'want', 'an', 'expert', 'personnel', 'in', 'the', 'field', 'of', 'creatingвЂ¦","в‚№25,000', 'a', 'month"']
# ['56,Accounts', 'Assistant,"New', 'Delhi,', 'Delhi+1', 'location","Shall', 'have', 'basic', 'knowledge', 'of', 'accounts', 'shall', 'know', 'how', 'to', 'operate', 'computer', 'very', 'well.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Internship,', 'Fresher.",NA']
# ['57,Content', 'Writer', '(Work', 'From', 'Home),"Remote', 'in', 'Chennai,', 'Tamil', 'Nadu","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.']
# ['You', 'have', 'to', 'write', 'on', 'various', 'niches', 'like', 'software,', 'technical,', 'home', 'products,', 'etc.","в‚№15,000', '-', 'в‚№20,000', 'a', 'month"']
# ['58,School', 'Administrator,"Delhi,', 'Delhi",We', 'are', 'looking', 'for', 'School', 'Administrator', 'with', 'Graduate', 'Degree', 'in', 'any', 'stream', 'along', 'with', '2-10', 'years', 'of', 'experience', 'in', 'the', 'the', 'same', 'or', 'relevant', 'profile.,"в‚№25,788', '-', 'в‚№40,000', 'a', 'month"']
# ['59,Bpo', 'telecaller,"Remote', 'in', 'Bengaluru,', 'Karnataka","Part-time', 'hours:', '48', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Volunteer,', 'Internship,', 'Fresher.']
# ['Higher', 'Secondary(12th', 'Pass)', '(Preferred).","в‚№23,000', '-', 'в‚№26,000', 'a', 'month"']
# ['60,newPersonal', 'Assistant,"Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Must', 'be', 'ok', 'with', 'exl.']
# ['Should', 'be', 'ok', 'with', 'travel', 'in', 'delhi', 'ncr', 'and', 'pan', 'india', 'if', 'required.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№35,000', '-', 'в‚№55,000', 'a', 'month"']
# ['61,Computer', 'Operator,"New', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Experience', 'of', 'Computers', '(MS', 'Word,', 'Excel,', 'Power', 'Point),', 'Emails,', 'Good', 'Typing', 'Speed.","в‚№6,000', '-', 'в‚№10,000', 'a', 'month"']
# ['62,newInventory', 'Manager,"New', 'Delhi,', 'Delhi","Each', 'and', 'every', 'physical', 'stock', 'should', 'match', 'with', 'our', 'stock', 'reflecting', 'with', 'software', 'data.*.']
# ['Part-time', 'hours:', '5', 'per', 'week.","в‚№2,000', '-', 'в‚№8,000', 'a', 'month"']
# ['63,Policy', 'Writing', 'Internships,"New', 'Delhi,', 'Delhi",Who', 'can', 'apply', 'вЂ“', 'Students', 'pursuing', 'or', 'completed', 'degree', 'in', 'any', 'stream', 'interested', 'in', 'Policy', 'research', 'and', 'writing', 'policy', 'briefs', 'are', 'welcome', 'to', 'applyвЂ¦,NA']
# ['64,Excel', 'Project', 'Developer-Contract', 'Position,"Remote', 'in', 'Punjabi', 'Bagh,', 'Delhi,', 'Delhi","In', 'Spreadsheet', 'we', 'need', 'to', 'add', 'hours', 'with', 'key', 'in', 'for', 'each', 'employee,', 'studentsвЂ™', 'classes', 'even', 'when', 'they', 'weekly', 'get', 'the', 'schedule', 'on', 'hourly', 'basis', 'and', 'determineвЂ¦","в‚№8,000', '-', 'в‚№15,000', 'a', 'week"']
# ['65,newAccountant', 'cum', 'Office', 'Assistant,"Gurgaon,', 'Haryana","Looking', 'for', 'full-time', 'Accountant', 'cum', 'office', 'assistance', 'with', 'a', 'good', 'knowledge', 'of', 'Tally', 'ERP', '.']
# ['Maintaining', 'office', 'equipment', 'as', 'needed.","в‚№12,651', '-', 'в‚№33,780', 'a', 'month"']
# ['66,newMTR', 'Milling', 'MachineOperator,"Sonipat,', 'Haryana","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.']
# ['Sonipat,', 'Haryana:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', '(Required).","в‚№20,000', '-', 'в‚№28,000', 'a', 'month"']
# ['67,newRequired', 'Educators,"Temporarily', 'Remote', 'in', 'Jaipur,', 'Rajasthan","Part-time', 'hours:', '24', 'per', 'week.']
# ['You', 'can', 'work', 'from', 'home', 'but', 'you', 'must', 'have', 'setup', 'for', 'online', 'teaching', '(Laptop,', 'Pen', 'tablet', 'and', 'webcam).",NA']
# ['68,General', 'administrative', 'tasks,"Remote', 'in', 'Delhi,', 'Delhi","You', 'have', 'high-speed', 'internet', 'and', 'a', 'computer', 'less', 'than', '3', 'years', 'old', 'with', 'updated', 'software.']
# ['Per', 'day', 'from', '8-11', 'am', 'PST', '(you', 'must', 'be', 'a', 'person', 'who', 'likes', 'to', 'stay', 'upвЂ¦","в‚№25,000', 'a', 'month"']
# ['69,Catalogue', 'Executives,"Gurgaon,', 'Haryana","All', 'positions', 'are', 'based', 'out', 'of', 'our', 'Gurgaon', 'office', 'Catalogue', 'Executives', 'Your', 'job', 'involves', 'surfing', 'the', 'net,', 'gathering', 'knowledge,', 'sipping', 'a', 'coffee', 'andвЂ¦..', 'Whoa,вЂ¦",NA']
# ['70,Marketing', 'Manager,"Remote', 'in', 'Noida,', 'Uttar', 'Pradesh","Part-time', 'hours:', '20', 'per', 'week.']
# ['Go', 'the', 'extra', 'mile', '(Go', 'above', 'and', 'beyond,', 'go', 'beyond', 'the', 'call', 'of', 'duty,', 'go', 'get', 'it', 'done', 'on', 'time).","в‚№10,00,000', 'a', 'year"']
# ['71,Lecturer,"Delhi,', 'Delhi","Part-time', 'hours:', '3-4', 'per', 'week.']
# ['Delhi,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', '(Preferred).']
# ['Total', 'work:', '1', 'year', '(Preferred).",в‚№400', '-', 'в‚№500', 'an', 'hour']
# ['72,.Net', 'Developer', '(Part', 'Time),"Remote', 'in', 'Delhi,', 'Delhi+2', 'locations","Job', 'Types:', 'Part-time,', 'Regular', '/', 'Permanent,', 'Freelance.']
# ['NET', 'Developer', 'for', '1', 'year.']
# ['Write', 'clean,', 'testable', 'code', 'using', '.']
# ['Total', 'work:', '1', 'year', '(Required).","в‚№5,000', '-', 'в‚№15,000', 'a', 'month"']
# ['73,Social', 'Media', 'Manager', 'and', 'Content', 'Creator,"New', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Looking', 'for', 'tech', 'savvy', 'candidates', 'with', 'fluency', 'in', 'English', 'and', 'Hindi', 'to', 'write,', 'create', 'and', 'manage', 'content', 'for', 'social', 'media,', 'blogsвЂ¦","в‚№8,000', '-', 'в‚№15,000', 'a', 'month"']
# ['74,Computer', 'Teacher,"New', 'Delhi,', 'Delhi",The', 'ability', 'to', 'deliver', 'Computer', 'Science', 'at', 'Institute', 'is', 'highly', 'desirable', 'and', 'should', 'have', 'basic', 'and', 'advanced', 'computer', 'skills', 'and', 'programming', 'languages', 'likeвЂ¦,"в‚№400', '-', 'в‚№1,000', 'an', 'hour"']
# ['75,Content', 'Writer,"Gurgaon,', 'Haryana","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Internship,', 'Fresher.']
# ['Content', 'writing:', '1', 'year', '(Preferred).","в‚№15,000', '-', 'в‚№50,000', 'a', 'month"']
# ['76,Quality', 'Analyst,"Temporarily', 'Remote', 'in', 'Gurgaon,', 'Haryana","Part-time', 'hours:', '20-25', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Freelance.']
# ['Strong', 'knowledge', 'of', 'unit', 'testing,', 'smoke', 'testing,', 'sanity', 'testing,re-testing,', 'E2E', 'testing,вЂ¦","в‚№10,000', '-', 'в‚№15,000', 'a', 'month"']
# ['77,Computer', 'operater,"Delhi,', 'Delhi",Computer', 'operators', '*monitor', 'and', 'control', 'computer', 'and', 'electronic', 'data', 'processing', 'equipment', 'according', 'to', 'standardized', 'operating', 'instructions*.,"в‚№12,000', 'a', 'month"']
# ['78,Office', 'Manager,"Remote', 'in', 'Palam', 'Vihar,', 'Delhi,', 'Delhi","Part-time', 'hours:', '20-25', 'per', 'week.']
# ['Education:', 'Any', 'one,', 'as', 'long', 'as', 'the', 'candidate', 'is', 'well', 'versed', 'with', 'basic', 'computer', 'knowledge', 'and', 'English', 'Language.","в‚№7,000', '-', 'в‚№10,000', 'a', 'month"']
# ['79,Investigator,"Remote', 'in', 'Chandigarh,', 'Chandigarh","Total', 'work:', '10', 'years', '(Preferred).']
# ['Investigators', '(Part-time,', 'on', 'contractual', 'basis)*.']
# ['Involves', 'travel', 'within', 'India', 'and', 'could', 'be', 'state', 'specific.","в‚№50,000', 'a', 'month"']
# ['80,newwedding', 'video', 'editor,"Remote', 'in', 'Delhi,', 'Delhi","Part-time', 'hours:', '60', 'per', 'week.']
# ['Job', 'Types:', 'Full-time', '/', 'Part-time.']
# ['Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Min.', '2', 'years', 'of', 'experience.']
# ['Video', 'Editing:', '2', 'years', '(Preferred).","в‚№60,000', 'a', 'month"']
# ['81,newAcademic', 'Content', 'Writer,"Remote', 'in', 'Guwahati,', 'Assam","The', 'candidate', 'must', 'properly', 'carry', 'out', 'their', 'responsibilities', 'within', 'the', 'organization.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Freelance,вЂ¦","в‚№7,000', '-', 'в‚№15,000', 'a', 'month"']
# ['82,newAccounts', 'Assistant,Remote,"Part-time', 'hours:', '20', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Regular', '/', 'Permanent,', 'Freelance.']
# ['Looking', 'for', 'someone', 'experience', 'with', 'bookkeeping', 'and', 'tax', 'returns.","в‚№1,50,000', '-', 'в‚№2,00,000', 'a', 'year"']
# ['83,Digital', 'Designer,"Delhi,', 'Delhi","Compensation', 'on', 'per', 'design', 'basis,', 'regular', 'work', 'to', 'be', 'offered', 'around', '15-20', 'designs', 'per', 'month.']
# ['Part-time', 'hours:', '10', 'per', 'week.","в‚№4,000', '-', 'в‚№5,000', 'a', 'day"']
# ['84,BUS', 'COMPANY', 'MANAGER', '/', 'BUS', 'TRANSPORT', 'SUPERVISOR', '/', 'SCHOOL', 'BUS...,"Gurgaon,', 'Haryana","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.']
# ['Gurugram,', 'Haryana:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', '(Required).","в‚№10,086', '-', 'в‚№20,284', 'a', 'month"']
# ['85,Accounts', 'Assistant,"Sarai', 'Rohilla,', 'Delhi,', 'Delhi+1', 'location","Need', 'an', 'accounts', 'executive', 'who', 'has', 'complete', 'knowledge', 'of', 'filling', 'Gst,', 'Esi', '/', 'PF', 'basic', 'accounts', 'and', 'accounting', 'also', 'can', 'work', 'on', 'excel', 'completely,', 'Should', 'beвЂ¦","в‚№16,000', 'a', 'month"']
# ['86,Academic', 'Content', 'Writer', '(Gurugram)', '(Work', 'From', 'Office),"Remote', 'in', 'Sohna,', 'Haryana","Ability', 'to', 'research', 'on', 'the', 'internet.']
# ['Job', 'Type', 'вЂ“', 'Office', 'Job', '(No', 'WFH,', 'freelancing', 'or', 'Part-time).']
# ['Good', 'Communication', 'skills', 'in', 'English.","в‚№2,00,000', '-', 'в‚№4,00,000', 'a', 'year"']
# ['87,newMarket', 'Research', 'Intern,"Temporarily', 'Remote', 'in', 'Gurgaon,', 'Haryana","Work', 'on', 'data', 'entry.']
# ['Part-time', 'hours:', '35', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Internship.']
# ['Interaction', 'with', 'Key', 'Opinion', 'Leaders.","в‚№12,000', '-', 'в‚№16,000', 'a', 'month"']
# ['88,School', 'Administrator,"Delhi,', 'Delhi",We', 'are', 'looking', 'for', 'School', 'Administrator', 'with', 'Graduate', 'Degree', 'in', 'any', 'stream', 'along', 'with', '2-10', 'years', 'of', 'experience', 'in', 'the', 'the', 'same', 'or', 'relevant', 'profile.,"в‚№25,788', '-', 'в‚№40,000', 'a', 'month"']
# ['89,FACULTY', 'FOR', 'MANAGEMENT', 'COURSES,"Jaipur,', 'Rajasthan","Part-time', 'hours:', '20', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance.']
# ['We', 'are', 'open', 'to', 'colleagues', 'who', 'have', 'received', '(or', 'are', 'receiving)', 'a', 'Ph.D.', 'in', 'Marketing', '/вЂ¦","в‚№25,000', '-', 'в‚№60,000', 'a', 'month"']
# ['90,newbackend,"New', 'Delhi,', 'Delhi","Backend', 'office', 'work,', 'Must', 'be', 'good', 'in', 'using', 'Ms', 'Office,', 'data', 'entry,', 'Computer', 'Savy.']
# ['Part', 'time', 'job', 'starting', 'from', '20', 'June', "'22", '-', '10', 'July\'22.",в‚№300', 'a', 'day']
# ['91,newHR', 'Executive,"Remote', 'in', 'Shahdara,', 'Delhi,', 'Delhi","Maintain', 'employee', 'records', '(attendance,', 'EEO', 'data', 'etc.)', 'according', 'to', 'policy', 'and', 'legal', 'requirements.']
# ['Salary', 'will', 'be', 'between', 'the', 'range', 'of', '18,000-23,000', 'per', 'month.","в‚№18,000', '-', 'в‚№23,000', 'a', 'month"']
# ['92,newFreelance', 'Content', 'Writer,"Bengaluru,', 'Karnataka","Part-time', 'hours:', '6', 'per', 'week.']
# ['Total', 'work:', '1', 'year', '(Required).","в‚№5,000', 'a', 'month"']
# ['93,newTelecaller,"Ludhiana,', 'Punjab","Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance,', 'Fresher.']
# ['CANDIDATE', 'SHOULD', 'HAVE', 'BASIC', 'KNOWLEDGE', 'OF', 'MS', 'EXCEL', 'and', 'should', 'be', 'female.","в‚№20,000', 'a', 'month"']
# ['94,newField', 'verification', 'executive,"Delhi,', 'Delhi","Job', 'Types:', 'Part-time,', 'Freelance.']
# ['Higher', 'Secondary(12th', 'Pass)', '(Preferred).']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№9,000', '-', 'в‚№12,000', 'a', 'month"']
# ['95,newCommunication', 'consultant', '(Part-time),"Gurgaon,', 'Haryana","The', 'part-time', 'role', 'will', 'require', 'a', 'commitment', 'of', '2', 'days', 'per', 'week', 'up', 'to', 'three', 'months.']
# ['A', 'minimum', 'of', '2+', 'years', 'of', 'work', 'experience', 'in', 'communications,', 'stakeholderвЂ¦",NA']
# ['96,General', 'administrative', 'tasks,"Remote', 'in', 'Delhi,', 'Delhi","You', 'have', 'high-speed', 'internet', 'and', 'a', 'computer', 'less', 'than', '3', 'years', 'old', 'with', 'updated', 'software.']
# ['Per', 'day', 'from', '8-11', 'am', 'PST', '(you', 'must', 'be', 'a', 'person', 'who', 'likes', 'to', 'stay', 'upвЂ¦","в‚№25,000', 'a', 'month"']
# ['97,newHR', 'Executive,"Remote', 'in', 'Dispur,', 'Assam+3', 'locations","Part-time', 'hours:', '21-30', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Freelance.']
# ['Candidates', 'should', 'fulfill', 'target', 'on', 'time.","в‚№10,000', '-', 'в‚№12,000', 'a', 'month"']
# ['98,Social', 'Media', 'and', 'Marketing', 'Intern,"Remote', 'in', 'Gurgaon,', 'Haryana","Part-time', 'hours:', '10', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Looking', 'for', 'a', 'social', 'media', 'and', 'marketing', 'person', 'to', 'run', 'promotions', ',', 'target', 'events', 'for', 'the', 'brand,вЂ¦","в‚№8,000', '-', 'в‚№10,000', 'a', 'month"']
# ['99,Math', 'assessment', 'developer,"Delhi,', 'Delhi","Part-time', 'hours:', '20', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Fresher.']
# ['\\*', 'Preparing', 'Test', 'questions', 'for', 'K-12', 'in', 'the', 'area', 'ofвЂ¦","в‚№18,000', 'a', 'month"']
# ['100,newGraphic', 'Designer', 'Intern', '(fresher),"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Collaborate', 'closely', 'with', 'our', 'Brand', 'Design', 'team', 'to', 'translate', 'the', 'expression', 'of', 'our', 'brand', 'identity', 'into', 'our', 'user', 'experiences.","в‚№1,000', '-', 'в‚№2,000', 'a', 'month"']
# ['101,newPart-time', 'Nutritionist,"Green', 'Park,', 'Delhi,', 'Delhi","Candidates', 'are', 'required', 'to', 'come', 'to', 'office', '5', 'days', 'a', 'week', '(for', '5', 'hours', 'per', 'day).']
# ['Part-time', 'hours:', '30', 'per', 'week.']
# ['Total', 'work:', '5', 'years', '(Required).","в‚№8,000', '-', 'в‚№10,000', 'a', 'month"']
# ['102,newInventory', 'Manager,"New', 'Delhi,', 'Delhi","Each', 'and', 'every', 'physical', 'stock', 'should', 'match', 'with', 'our', 'stock', 'reflecting', 'with', 'software', 'data.*.']
# ['Part-time', 'hours:', '5', 'per', 'week.","в‚№2,000', '-', 'в‚№8,000', 'a', 'month"']
# ['103,newContent', "Writer's", 'Paid', 'Internship,"Remote', 'in', 'Guwahati,', 'Assam","Part-time', 'hours:', '4-5', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Freelance,', 'Internship,', 'Fresher.']
# ['Bonus:', 'в‚№3000', 'based', 'on', 'quality', 'of', 'work', 'after', 'completion', 'of', 'three', 'months', '+вЂ¦","в‚№5,500', 'a', 'month"']
# ['104,newContent', 'Writer,"Visakhapatnam,', 'Andhra', 'Pradesh","Candidates', 'must', 'have', 'a', 'good', 'PC/Laptop', 'with', 'an', 'internet', 'connection.']
# ['Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Excellent', 'interpersonal', 'and', 'English', 'written', 'skills.","в‚№12,000', '-', 'в‚№15,000', 'a', 'month"']
# ['105,Business', 'Development', 'Officer,"Remote', 'in', 'Gautam', 'Budh', 'Nagar,', 'Uttar', 'Pradesh","Comfortable', 'using', 'a', 'computer', 'for', 'various', 'tasks.']
# ['Job', 'Types:', 'Part-time,', 'Contractual', '/', 'Temporary.']
# ['To', 'excel', 'in', 'this', 'role', 'you', 'should', 'be', 'an', 'active', 'listener,', 'have', 'aвЂ¦","в‚№80,000', '-', 'в‚№1,00,000', 'a', 'month"']
# ['106,Creative', 'Copywriter,"Gurgaon,', 'Haryana","*Stay', 'up', 'to', 'speed', 'with', 'relevant', 'trends', 'within', 'the', 'retail/eCommerce', 'industry.*.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance.']
# ['Online', 'store', 'banners', 'and', 'headlines.","в‚№25,000', '-', 'в‚№40,000', 'a', 'month"']
# ['107,newGraphic', 'Designer', 'Intern', '(fresher),"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Collaborate', 'closely', 'with', 'our', 'Brand', 'Design', 'team', 'to', 'translate', 'the', 'expression', 'of', 'our', 'brand', 'identity', 'into', 'our', 'user', 'experiences.","в‚№1,000', '-', 'в‚№2,000', 'a', 'month"']
# ['108,newSocial', 'Media', 'Graphics', 'Designer,"Delhi,', 'Delhi","Must', 'have', 'above', 'average', 'communication', 'skills.']
# ['Internship', 'type:', 'Full-time', '(hybrid).']
# ['Part-time', 'hours:', '50', 'per', 'week.']
# ['Should', 'have', 'a', 'flair', 'for', 'social', 'media', 'marketing.","в‚№14,000', '-', 'в‚№18,000', 'a', 'month"']
# ['109,newAccountant,"Gurgaon,', 'Haryana","Part-time', 'hours:', '60', 'per', 'week.']
# ['Publish', 'financial', 'statements', 'in', 'time.']
# ['Hands-on', 'experience', 'with', 'accounting', 'software', 'like', 'TALLY.']
# ['Knowledge', 'of', 'GST,', 'TDS', 'etc.","в‚№17,000', '-', 'в‚№20,000', 'a', 'month"']
# ['110,Video', 'Editor', '-', 'Top', '10', 'Style,"Delhi,', 'Delhi","Part-time', 'hours:', '20', 'per', 'week.']
# ['Regular', 'Work', 'and', 'Good', 'Pay', 'per', 'project.']
# ['We', 'are', 'looking', 'for', 'a', 'Youtube', 'editor', 'who', 'can', 'edit', 'top', '10', 'style', 'YouTube', 'videos.","в‚№8,350', '-', 'в‚№29,097', 'a', 'month"']
# ['111,Subject', 'Matter', 'Experts/Academic', 'Writers,"Noida,', 'Uttar', 'Pradesh","This', 'is', 'both', 'Full-time/Part', 'time', 'job', 'opportunity', 'depending', 'on', 'the', 'convenience', 'of', 'the', 'candidate.']
# ['Digiversal', 'is', 'looking', 'for', 'full', 'time', 'writers/researchers', 'to', 'workвЂ¦",NA']
# ['112,newNeed', 'Tutors,"Lucknow,', 'Uttar', 'Pradesh","Part-time', 'hours:', '36', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Freelance,', 'Fresher.']
# ['Lucknow,', 'Uttar', 'Pradesh:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', 'вЂ¦","в‚№6,000', '-', 'в‚№20,000', 'a', 'month"']
# ['113,newTeam', 'Member,"Noida,', 'Uttar', 'Pradesh+5', 'locations","*Performs', 'order', 'processing', 'вЂ“', 'Process', 'the', 'recipes', 'accurately', 'as', 'per', 'the', 'process', 'in', 'a', 'fast', 'and', 'timely', 'manner.']
# ['10*.', 'Ensures', 'fast', 'and', 'timely', 'service', 'to', 'customers,вЂ¦","в‚№13,000', '-', 'в‚№15,000', 'a', 'month"']
# ['114,newBusiness', 'Development', 'Intern,"Noida,', 'Uttar', 'Pradesh","Job', 'Types:', 'Full-time,', 'Part-time,', 'Internship.']
# ['Job', 'Types*:', 'Full-time,', 'Part-time,', 'Internship,', 'Fresher.']
# ['Learns', 'and', 'becomes', 'proficient', 'on', 'internal', 'software', 'systems.",NA']
# ['115,newEsi', 'And', 'Pf', 'Consultant,"Greater', 'Noida,', 'Uttar', 'Pradesh","Part-time', 'hours:', '20', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Internship,', 'Fresher.","в‚№8,000', '-', 'в‚№20,000', 'a', 'month"']
# ['116,newDistrict', 'Manager,"Remote', 'in', 'Dhanbad,', 'Jharkhand","Part-time', 'hours:', '21', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Fresher.']
# ['Dhanbad,', 'Dhanbad', '-', '826001,', 'Jharkhand:', 'Reliably', 'commute', 'or', 'planningвЂ¦","в‚№20,000', 'a', 'month"']
# ['117,newArticle', 'Writer,"Remote', 'in', 'Jammu,', 'Jammu', 'and', 'Kashmir",I', 'recently', 'started', 'this', 'word', 'and', 'I', 'need', 'hardworking', 'and', 'trustworthy', 'people', 'who', 'know', 'the', 'knowledge', 'of', 'how', 'to', 'type', 'and', 'post', 'an', 'article', 'regarding', 'news', 'with', 'noвЂ¦,NA']
# ['118,Business', 'Development', '(Part-time', 'WFH),Remote,"Be', 'available', 'for', 'minimum', 'of', '4', 'hours', 'per', 'day.']
# ['Part-time', 'hours:', '4', 'per', 'week.']
# ['Maintain', 'call', 'records', 'and', 'follow', 'up', 'as', 'per', 'schedule.","в‚№10,000', 'a', 'month"']
# ['119,newFinance', 'Assistant,"Remote', 'in', 'Bengaluru,', 'Karnataka",We', 'are', 'Hiring', 'for', "Leader's", 'who', 'have', 'good', 'experience', 'in', 'Banking', 'and', 'Any', 'Financial', 'sector', 'any', 'apply', 'and', 'also', 'having', 'very', 'good', 'customer', 'contact', '.,"в‚№30,000', '-', 'в‚№50,000', 'a', 'month"']
# ['120,newOnline', 'Marketing', 'Executive,"New', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['We', 'are', 'looking', 'for', 'Good', '&', 'Experienced', 'Candidate', 'proficient', 'in', 'online', 'selling', 'on', 'various', 'ecommerce', 'websites', 'like', 'Amazon,вЂ¦","в‚№9,988', '-', 'в‚№37,669', 'a', 'month"']
# ['121,Content', 'Writer,+1', 'locationRemote,"Part-time', 'hours:', '45', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Volunteer,', 'Internship,', 'Fresher.","в‚№3,000', 'a', 'month"']
# ['122,Real', 'Estate', 'Agent,"Delhi,', 'Delhi","All', 'candidates', 'must', 'be', 'vaccinated', 'and', 'use', 'facemask', 'and', 'maintain', 'social', 'distance', 'on', 'daily', 'basis.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance,', 'Fresher.","в‚№20,000', 'a', 'month"']
# ['123,Content', 'Writer', 'Intern,"New', 'Delhi,', 'Delhi","Job', 'Types:', 'Part-time,', 'Internship.']
# ['Prepare', 'blogs', 'for', 'the', 'website.']
# ['Prepare', 'content', 'for', 'email', 'campaigns.']
# ['Co-ordinate', 'with', 'the', 'marketing', 'team', 'for', 'the', 'content.","в‚№1,000', 'a', 'month"']
# ['124,Subject', 'Matter', 'Expert,"Delhi,', 'Delhi","Prefer', 'candidates', 'with', 'Math', 'Background(Undergrads', 'can', 'also', 'apply).']
# ['Job', 'Types:', 'Part-time,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Fresher.","в‚№18,000', 'a', 'month"']
# ['125,newCashier/Sales', 'Assistant,"Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Yes', 'vivid', 'protocols', 'are', 'followed.']
# ['Delhi,', 'Delhi', '-', '110051,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', 'вЂ¦","в‚№12,000', '-', 'в‚№15,000', 'a', 'month"']
# ['126,Marketing', 'Manager,"Remote', 'in', 'Noida,', 'Uttar', 'Pradesh","Part-time', 'hours:', '20', 'per', 'week.']
# ['Go', 'the', 'extra', 'mile', '(Go', 'above', 'and', 'beyond,', 'go', 'beyond', 'the', 'call', 'of', 'duty,', 'go', 'get', 'it', 'done', 'on', 'time).","в‚№10,00,000', 'a', 'year"']
# ['127,newData', 'Entry', 'Work,"New', 'Alipore,', 'Kolkata,', 'West', 'Bengal","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Higher', 'Secondary(12th', 'Pass)', '(Preferred).","в‚№8,000', '-', 'в‚№9,000', 'a', 'month"']
# ['128,Fresh', 'Faces', 'For', 'Instagram', 'Profile', 'Collaboration,"Delhi,', 'Delhi","Part-time', 'hours:', '35', 'per', 'week.']
# ['Modeling', '&', 'Styling', 'For', 'The', 'Ethnic', 'Garment', 'Shoots', 'On', '30%', 'Collaboration', 'From', 'Scratch.']
# ['Modeling', 'For', 'New', 'Creative', 'Videos/Reels.","в‚№2,000', 'a', 'month"']
# ['129,Freelance', 'Content', 'Writer,"Remote', 'in', 'Faridabad,', 'Haryana","Part-time', 'hours:', '28', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Freelance,', 'Internship.']
# ['The', 'work', 'will', 'be', 'contract', 'based', '(Avg', 'Monthly', 'income', 'will', 'be', '30-15k),', 'more.","в‚№15,000', 'a', 'month"']
# ['130,Academic', 'Content', 'Writer', '(Gurugram)', '(Work', 'From', 'Office),"Remote', 'in', 'Sohna,', 'Haryana","Ability', 'to', 'research', 'on', 'the', 'internet.']
# ['Job', 'Type', 'вЂ“', 'Office', 'Job', '(No', 'WFH,', 'freelancing', 'or', 'Part-time).']
# ['Good', 'Communication', 'skills', 'in', 'English.","в‚№2,00,000', '-', 'в‚№4,00,000', 'a', 'year"']
# ['131,HR', 'and', 'Operation', 'Head', 'Intern,Remote,"Generate', 'reports', 'and', 'data', 'of', 'the', 'team.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Internship,', 'Fresher.']
# ['Ensure', 'that', 'the', 'project', 'is', 'delivered', 'on', 'time,', 'within', 'scope,', 'andвЂ¦",NA']
# ['132,newBusiness', 'Development', 'Executive', '(BDE),"Remote', 'in', 'Noida,', 'Uttar', 'Pradesh","Good', 'communication', 'skills', '(English', 'or', 'Hindi', 'both', 'will', 'work).']
# ['Training', 'sessions', 'that', 'will', 'be', 'provided', 'by', 'us', 'and', '35', 'account', 'is', 'minimum', 'target,.","в‚№10,000', 'a', 'month"']
# ['133,Content', 'Writer,"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '40', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Freelance,', 'Volunteer,', 'Internship,', 'Fresher.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№9,000', '-', 'в‚№15,000', 'a', 'month"']
# ['134,newData', 'Entry', 'Operator,"Sahar,', 'Mumbai,', 'Maharashtra","Part-time', 'hours:', '48', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Fresher.']
# ['AGE', 'LIMIT', '18', 'TO', '30', 'YRS.']
# ['Microsoft', 'Office:', '1', 'year', '(Preferred).","в‚№24,000', 'a', 'month"']
# ['135,Freelance', '&', 'Part', 'Time', 'Editors,"New', 'Delhi,', 'Delhi",Careers', 'Champak', 'magazine', 'is', 'looking', 'for', 'freelance', 'and', 'partime', 'editors', 'for', 'their', 'book', 'publishing', 'division.', 'Pls', 'send', 'your', 'resume', 'at', 'jobseditorial@delhipressвЂ¦,NA']
# ['136,BLOOD', 'BANK', 'OFFICER/INCHARGE', '(PART', 'TIME),"New', 'Delhi,', 'Delhi","Job', 'Code', ':', 'DHLI/HR/18/05/2022', 'No', 'of', 'Position', ':', '01', 'Job', 'Description', 'MBBS,', 'MD(Pathology)', 'with', 'min', '4-5', 'yrs', 'exp', 'as', 'Blood', 'Bank', 'Officer/Incharge', 'in', 'NABHвЂ¦",NA']
# ['137,newEvent', 'Planner,"Gurgaon,', 'Haryana","Part-time', 'hours:', '40', 'per', 'week.']
# ['Plan', 'and', 'organize', 'events', 'with', 'attention', 'to', 'financial', 'and', 'time', 'constraints.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,вЂ¦","в‚№15,000', 'a', 'month"']
# ['138,newVideo', 'Editor,"Remote', 'in', 'Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Job', 'Types:', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary.']
# ['Strong', 'time', 'management,', 'organization,', 'problem-solving,', 'andвЂ¦","в‚№9,000', 'a', 'month"']
# ['139,newMobilizer,"Remote', 'in', 'Alwar,', 'Rajasthan","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Internship,', 'Fresher.']
# ['Data', 'collection', 'and', 'Call', 'to', 'students.","в‚№8,000', '-', 'в‚№15,000', 'a', 'month"']
# ['140,newSchool', 'Transport', 'Supervisor,"Gurgaon,', 'Haryana","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Manage', 'school', 'busses,', 'Driver/', 'Helper/', 'Other', 'Busses.']
# ['Gurugram,', 'Gurugram', '-', '122006,', 'Haryana:', 'Reliably', 'commute', 'or', 'planning', 'toвЂ¦","в‚№23,000', 'a', 'month"']
# ['141,Sales', 'Assistant,"Remote', 'in', 'Delhi,', 'Delhi","Part-time', 'hours:', '4', 'per', 'week.']
# ['7000/-', 'as', 'stipend', 'and', 'companyвЂ™s', 'training', 'certificate,', 'on', 'successfully', 'selling', 'life', 'insurance', 'policy', 'with', 'minimum', 'premium', 'of', 'Rs.","в‚№7,000', '-', 'в‚№20,000', 'a', 'month"']
# ['142,Gym', 'Receptionist,"Delhi,', 'Delhi",The', 'candidate', 'must', 'know', 'about', 'the', 'basic', 'computer', 'and', 'know', 'a', 'bit', 'about', 'excel', 'e.g', 'familiar', 'with', 'the', 'data', 'entries.,"в‚№10,000', '-', 'в‚№12,000', 'a', 'month"']
# ['143,newHR', 'Recruiter,"Noida,', 'Uttar', 'Pradesh","Part-time', 'hours:', '4', 'per', 'week.']
# ['This', 'role', 'is', 'for', 'part', 'time', 'from', 'Noida', 'office.']
# ['Responsible', 'for', 'achieving', 'a', 'good', 'conversion', 'ratio', 'of', 'submitting', 'into', 'interview', 'andвЂ¦","в‚№8,086', '-', 'в‚№20,000', 'a', 'month"']
# ['144,newEsi', 'And', 'Pf', 'Consultant,"Greater', 'Noida,', 'Uttar', 'Pradesh","Part-time', 'hours:', '20', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Internship,', 'Fresher.","в‚№8,000', '-', 'в‚№20,000', 'a', 'month"']
# ['145,newTelesales,"Kailash,', 'Delhi+1', 'location","Part-time', 'hours:', '54', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance,', 'Fresher.']
# ['Higher', 'Secondary(12th', 'Pass)', '(Preferred).']
# ['Total', 'work:', '1', 'year', '(Required).","в‚№8,000', '-', 'в‚№25,000', 'a', 'month"']
# ['146,newHR', 'Executive,"Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Yes', 'vivid', 'protocols', 'are', 'followed.']
# ['Delhi,', 'Delhi,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', '(PreferredвЂ¦","в‚№15,000', '-', 'в‚№25,000', 'a', 'month"']
# ['147,Part', 'Time', 'Calling', 'profile,"Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Those', 'who', 'are', 'looking', 'for', 'part', 'time', 'work.']
# ['Okhla,', 'Delhi,', 'Delhi,', 'Delhi', '-', '110020,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocateвЂ¦","в‚№8,000', '-', 'в‚№10,000', 'a', 'month"']
# ['148,newPHP', 'Developer,Remote,"Duration:', '*', 'Long', 'Term', '(minimum', '1', 'year).']
# ['Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Domain:', '*', 'Digital', 'Marketing', 'for', 'US', 'Colleges.']
# ['PHP', 'Developing:', '5', 'years', '(Preferred).","в‚№8,00,000', '-', 'в‚№13,00,000', 'a', 'year"']
# ['149,Content', 'Writer,"Remote', 'in', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Internship.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Internship,', 'Fresher.",NA']
# ['150,Transport', 'Supervisor,"Mayur', 'Vihar,', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent.']
# ['E', 'п‚·', 'Oversee', 'purchases', 'of', 'repair', 'parts', 'and', 'department', 'supplies.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№19,867', '-', 'в‚№20,034', 'a', 'month"']
# ['151,newVideo', 'Editor,"Chandigarh,', 'Chandigarh","Part-time', 'hours:', '25', 'per', 'week.']
# ['Higher', 'Secondary(12th', 'Pass)', '(Preferred).']
# ['Video', 'Editing:', '1', 'year', '(Preferred).']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№10,019', '-', 'в‚№20,000', 'a', 'month"']
# ['152,Computer', 'Teacher,"Laxmi', 'Nagar,', 'Delhi,', 'Delhi","We', 'are', 'looking', 'for', 'a', 'computer', 'trainer', 'who', 'has', 'a', 'good', 'command', 'of', 'adv', 'excel', 'basic', 'computer', 'Tally.']
# ['Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№12,000', '-', 'в‚№18,000', 'a', 'month"']
# ['153,newSocial', 'Media', 'Executive,"Greater', 'Kailash', 'II,', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Social', 'media', 'marketing:', '1', 'year', '(Preferred).']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№20,000', '-', 'в‚№30,000', 'a', 'month"']
# ['154,newHuman', 'Resources', 'Internship,"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Available', 'immediately', 'to', 'start', 'with', 'the', 'internship', 'position.']
# ['Helping', 'the', 'organization', 'expand', 'their', 'reach.","в‚№1,000', '-', 'в‚№2,000', 'a', 'month"']
# ['155,Telecaller,"Connaught', 'Place,', 'Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Updating', 'feedback', 'on', 'excel', 'sheet.']
# ['Good', 'communication', 'skills', 'required', '(', 'English).']
# ['Calling', 'required', 'from', '12noon', 'to', '5pm.","в‚№8,000', 'a', 'month"']
# ['156,Social', 'Media', 'Manager,"New', 'Delhi,', 'Delhi","Keep', 'pace', 'with', 'social', 'media', 'and', 'internet', 'marketing', 'industry', 'trends', 'and', 'developments.']
# ['Part-time', 'hours:', '40', 'per', 'week.']
# ['Social', 'Media', 'Occupations:', '1', 'year', '(Preferred).",NA']
# ['157,Sales', 'Manager,"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '45', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Internship.']
# ['Sharp', 'Eye', 'Infotech', 'is', 'Looking', 'for', 'the', 'Sales', 'and', 'MarketingвЂ¦","в‚№1,38,536', '-', 'в‚№6,69,016', 'a', 'year"']
# ['158,newContent', 'Writer,"Green', 'Park,', 'Delhi,', 'Delhi","Part-time', 'hours:', '20', 'per', 'week.']
# ['It', 'can', 'be', 'home', 'based', 'job', 'or', 'full', 'time', 'office', 'job.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Freelance.']
# ['Content', 'writing:', '1', 'year', '(Preferred).","в‚№12,000', '-', 'в‚№15,000', 'a', 'month"']
# ['159,Warehouse', 'Assistant,"Tihar,', 'Delhi","Part-time', 'hours:', '4', 'per', 'week.']
# ['We', 'have', 'urgent', 'requirement', 'for', 'warehouse', 'Worker', 'both', 'male', '&', 'Female', 'for', 'Part', 'Time', 'as', 'well', 'as', 'Full', 'Time.","в‚№5,000', 'a', 'month"']
# ['160,Human', 'Resources', 'Executive,"Remote', 'in', 'Delhi,', 'Delhi","Searching', 'for', 'the', 'right', 'candidate', 'as', 'per', 'the', 'client', 'requirement', 'through', 'various', 'job', 'portal.']
# ['Sourcing', 'as', 'per', 'the', 'requisitions', 'for', 'various', 'departments', 'and', 'furtherвЂ¦",NA']
# ['161,newHR', 'Internship,"Remote', 'in', 'Mumbai,', 'Maharashtra","Part-time', 'hours:', '25', 'per', 'week.']
# ['Pay:', 'в‚№5,000.00', 'per', 'month.']
# ['Job', 'Types:', 'Part-time,', 'Internship,', 'Fresher.']
# ['Documentation', '&', 'Negotiation', 'Maintain', 'Daily', 'tracker', '.","в‚№5,000', 'a', 'month"']
# ['162,Website', 'Manager,"Remote', 'in', 'Delhi,', 'Delhi","Part-time', 'hours:', '20', 'per', 'week.']
# ['Turn', 'raw', 'data', 'into', 'actionable', 'insights', '(funnel', 'conversion,', 'campaigns,', 'A/B', 'tests,', 'website', 'behavior,', 'customer', 'journey', 'experiments).","в‚№40,000', '-', 'в‚№75,000', 'a', 'month"']
# ['163,feild', 'executive,"New', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Fresher.']
# ['Job', 'Type', ':', '-', 'Full', 'Time', '&', 'Part', 'Time.","в‚№12,000', '-', 'в‚№15,000', 'a', 'month"']
# ['164,Creative,India,"Both', 'full-time', 'and', 'part-time', 'jobs', 'are', 'available.']
# ['By', 'adjusting', 'your', 'teaching', 'style', 'to', 'each', 'userвЂ™s', 'individual', 'skill', 'level,', 'you', 'maximise', 'his', 'or', 'her', 'understandingвЂ¦",NA']
# ['165,newPHP', 'Developer,Remote,"Duration:', '*', 'Long', 'Term', '(minimum', '1', 'year).']
# ['Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Domain:', '*', 'Digital', 'Marketing', 'for', 'US', 'Colleges.']
# ['PHP', 'Developing:', '5', 'years', '(Preferred).","в‚№8,00,000', '-', 'в‚№13,00,000', 'a', 'year"']
# ['166,Content', 'Writer,"Remote', 'in', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Internship.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Internship,', 'Fresher.",NA']
# ['167,newInterior', 'Designer,"Delhi,', 'Delhi","Part-time', 'hours:', '20', 'per', 'week.']
# ['WeвЂ™re', 'looking', 'for', 'a', 'candidate', 'who', 'can', 'join', 'us', 'with', 'zeal', 'to', 'learn', 'something', 'in', 'a', 'new', 'prospect.']
# ['Total', 'work:', '2', 'years', '(Required).","в‚№25,000', 'a', 'month"']
# ['168,Freelancer', 'Content', 'Writer,"Gurgaon,', 'Haryana","Job', 'Types:', 'Part-time,', 'Contractual', '/', 'Temporary,', 'Freelance,', 'Fresher.']
# ['Develop', 'grammatically', 'flawless', 'and', 'informative', 'content', 'on', 'different', 'niche.","в‚№10,000', '-', 'в‚№15,000', 'a', 'month"']
# ['169,newPower', 'BI', 'Developer,Remote,"This', 'will', 'be', 'a', 'contractual', 'role,', 'the', 'candidate', 'must', 'possess', 'at', 'least', '2', 'years', 'of', 'experience,', 'creating', 'and', 'developing', 'Dashboards', 'in', 'Power', 'BI', 'by', 'connecting', 'to', 'aвЂ¦","в‚№1,000', '-', 'в‚№3,000', 'a', 'day"']
# ['170,Business', 'Development', 'Officer,"Remote', 'in', 'Gautam', 'Budh', 'Nagar,', 'Uttar', 'Pradesh","Comfortable', 'using', 'a', 'computer', 'for', 'various', 'tasks.']
# ['Job', 'Types:', 'Part-time,', 'Contractual', '/', 'Temporary.']
# ['To', 'excel', 'in', 'this', 'role', 'you', 'should', 'be', 'an', 'active', 'listener,', 'have', 'aвЂ¦","в‚№80,000', '-', 'в‚№1,00,000', 'a', 'month"']
# ['171,newSEO', 'Executive,"Roorkee,', 'Uttarakhand","Weekly', 'tasks', 'will', 'be', 'provided', 'to', 'deliver', 'in', 'the', 'respective', 'time', 'span.']
# ['Job', 'Types:', 'Full-time,', 'Regular', '/', 'Permanent,', 'Fresher.']
# ['Total', 'work:', '1', 'year', '(Preferred).","в‚№15,500', '-', 'в‚№25,500', 'a', 'month"']
# ['172,newClient', 'Servicing', 'Executive,"Gurgaon,', 'Haryana","Part-time', 'hours:', '40', 'per', 'week.']
# ['Job', 'Types:', 'Full-time,', 'Part-time,', 'Regular', '/', 'Permanent,', 'Internship,', 'Fresher.']
# ['Inspiring', 'repeat', 'business', 'from', 'clients.","в‚№15,000', 'a', 'month"']
# ['173,newContent', 'Writer,"Remote', 'in', 'Bengaluru,', 'Karnataka","Attitude', 'and', 'passion', 'to', 'come', 'up', 'with', 'fresh', 'and', 'innovative', 'ideas', 'for', 'great', 'and', 'interesting', 'content.']
# ['Employment', 'Type:', 'Full', 'Time/Part', 'Time.","в‚№3,00,000', '-', 'в‚№6,00,000', 'a', 'year"']
# ['174,Tender', 'Executive,"Ashok', 'Vihar,', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time.']
# ['Ashok', 'Vihar,', 'Delhi', '-', '110052,', 'Delhi:', 'Reliably', 'commute', 'or', 'planning', 'to', 'relocate', 'before', 'starting', 'work', '(Preferred).","в‚№20,000', '-', 'в‚№25,000', 'a', 'month"']
# ['175,newHuman', 'Resources', 'Internship,"New', 'Delhi,', 'Delhi","Part-time', 'hours:', '30', 'per', 'week.']
# ['Available', 'immediately', 'to', 'start', 'with', 'the', 'internship', 'position.']
# ['Helping', 'the', 'organization', 'expand', 'their', 'reach.","в‚№1,000', '-', 'в‚№2,000', 'a', 'month"']
# ['176,Digital', 'Marketing', 'Intern,"Dwarka,', 'Delhi,', 'Delhi","Job', 'Types:', 'Full-time,', 'Part-time,', 'Internship.']
# ['We', 'are', 'hiring', 'interim', 'candidate', 'also', 'who', 'passed', 'out', 'and', 'have', 'any', 'diploma', 'in', 'digital', 'marketing.","в‚№9,000', '-', 'в‚№22,000', 'a', 'month"']
# ['177,Marketing', 'Intern,+1', 'locationRemote,"Part-time', 'hours:', '25-30', 'per', 'week.']
# ['Stipend', ':', 'в‚№2500-10000', '/-', 'For', 'Showdoctors.com', '(', 'Depends', 'on', 'joining', 'type).']
# ['Encourage', 'Medical', 'Equipment', 'Suppliers/', 'Doctors', 'to', 'beвЂ¦","в‚№10,000', 'a', 'month"']
# ['178,newCustomer', 'Support', 'Executive', 'cum', 'Telecalling,"Chennai,', 'Tamil', 'Nadu","Job', 'Types:', 'Part-time,', 'Regular', '/', 'Permanent,', 'Fresher.']
# ['The', 'primary', 'job', 'of', 'a', '*Customer', 'Support', 'Executive*', 'is', 'to', '*address', 'customer', 'issues', 'and', 'resolve', 'them', 'in', 'aвЂ¦","в‚№25,000', '-', 'в‚№35,000', 'a', 'month"']
# ['179,newCompetitive', 'Programming', 'with', 'C++,Remote,"Job', 'Types:', 'Part-time,', 'Contractual', '/', 'Temporary,', 'Freelance.']
# ['Required', 'Competitive', 'Programming', 'with', 'C++', 'Trainer', 'who', 'is', 'expert', 'in', 'topics', 'with', 'Problem', 'Solving', 'skills:вЂ¦",в‚№500', '-', 'в‚№800', 'an', 'hour']

# %%
with open('job.csv', 'r') as f:
    print(f.read())
    f.close()
# Out:
# ,title,location,summary,salary
# 0,Customer Care Proffessional (Voice),"Gurgaon, Haryana","MS office suites such as Excel, Word, PowerPoint.
# Enhance our customersвЂ™ experience by finding opportunities to offer products based on our CardmembersвЂ™ needs.","в‚№5,00,000 - в‚№9,50,000 a year"
# 1,newFreelance Writer - Work from Home,"Remote in Delhi, Delhi","Submit a minimum of 5 articles (an average of 1,000 words each) per month.
# Produce a minimum of 5 articles per month.
# Experience in writing travel content.","в‚№4,000 - в‚№15,000 a month"
# 2,Online Maths/Science Tutor for grades(1-7),Remote,"Taking a minimum of 3 Lectures in a day (Can take more if time permits) and a minimum of 6 days working (including weekends.
# Preferred timings 2 PM to 8 PM.",в‚№225 - в‚№350 an hour
# 3,Computer Operator,"New Delhi, Delhi","Job Types: Full-time, Part-time.
# Experience of Computers (MS Word, Excel, Power Point), Emails, Good Typing Speed.","в‚№6,000 - в‚№10,000 a month"
# 4,newFresher Hiring for documents verification process,"Malviya Nagar, Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent.
# Attend calls & revert to E-mails professionally to provide information about products and services, obtainвЂ¦","в‚№18,667 - в‚№34,655 a month"
# 5,Computer operater,"Delhi, Delhi",Computer operators *monitor and control computer and electronic data processing equipment according to standardized operating instructions*.,"в‚№12,000 a month"
# 6,newSpa Therapist,"Delhi, Delhi+1 location","Part-time hours: 15 per week.
# Candidate should possess good communication skill, must be hard working and flexible.
# Job Types: Full-time, Part-time.","в‚№52,000 - в‚№55,000 a month"
# 7,Data Entry Operator,"Lucknow, Uttar Pradesh","Knowledge Of computer is a must.
# Main work is, Data entry of Documents and Catalogues on the company server.
# Zero Experience Candidates can also apply.",в‚№25 - в‚№70 an hour
# 8,Freelance Content Writer,"Gurgaon, Haryana","Gurugram, Haryana: Reliably commute or planning to relocate before starting work (Required).
# Total work: 1 year (Preferred).","в‚№9,372 - в‚№40,473 a month"
# 9,Excel Project Developer-Contract Position,"Remote in Punjabi Bagh, Delhi, Delhi","In Spreadsheet we need to add hours with key in for each employee, studentsвЂ™ classes even when they weekly get the schedule on hourly basis and determineвЂ¦","в‚№8,000 - в‚№15,000 a week"
# 10,Urgent Requirement of Telecaller,"Tilak Nagar, Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Volunteer, Internship, Fresher.","в‚№15,000 - в‚№50,000 a month"
# 11,newWeb Content Writer,"Noida, Uttar Pradesh","Every website has a specific target audience and requires the most relevant content to attract business.
# We are looking to hire a A Website content writer orвЂ¦",в‚№8.56 - в‚№20.00 an hour
# 12,Academic Writer (Freelance),"Remote in Noida, Uttar Pradesh","The candidates must have good typing speed, the ability to write good quality content in English, the ability to do intensive research, a good understanding ofвЂ¦","в‚№10,000 - в‚№20,000 a month"
# 13,Data Entry Operator,"Darbhanga, Bihar","Required data entry operator with minimum speed 40.
# Part-time hours: 48 per week.
# Job Types: Full-time, Part-time, Contractual / Temporary, Freelance.","в‚№10,000 a month"
# 14,Content Writer,"Remote in Delhi, Delhi","Part-time hours: 56 per week.
# Job Types: Full-time, Part-time, Regular / Permanent.","в‚№21,000 a month"
# 15,newHR Recruiter,"Remote in Delhi, Delhi","Means he must be told how to do the establishment of communication and achieve the desired outcome.
# Part-time hours: 15 per week.",NA
# 16,newFront Desk Receptionist,"Ghaziabad, Uttar Pradesh","Part-time hours: 25 per week.
# Keep track of office supplies and place orders when required.
# Job Types: Part-time, Regular / Permanent, Fresher.","в‚№8,086 - в‚№10,000 a month"
# 17,newCall Center Executive,"New Delhi, Delhi","Part-time hours: 32 per week.
# Job Types: Full-time, Part-time, Freelance.
# Near Shanti palace hotel, New Delhi, Delhi: Reliably commute or planning to relocateвЂ¦","в‚№10,141 - в‚№15,000 a month"
# 18,Human Resources Internship,"Temporarily Remote in Delhi, Delhi+2 locations","All students pursuing under graduate degree/post graduate degree.
# Any graduate, digital marketing, social media marketing, email marketing.","в‚№6,000 - в‚№9,000 a month"
# 19,newQuality Analyst,"Chandigarh, Chandigarh","Analyse and verify customer accounts as per available data.
# Any Graduate or under-graduate with minimum 1 year of experience.","в‚№3,50,000 a month"
# 20,newCashier/Sales Assistant,"Delhi, Delhi","Job Types: Full-time, Part-time.
# Yes vivid protocols are followed.
# Delhi, Delhi - 110051, Delhi: Reliably commute or planning to relocate before starting work вЂ¦","в‚№12,000 - в‚№15,000 a month"
# 21,Social Media (Part-Time/Freelancer),"New Delhi, Delhi","Part-time hours: 5 per week.
# Job Types: Part-time, Contractual / Temporary, Freelance, Internship.
# Social media marketing: 1 year (Preferred).","в‚№7,000 - в‚№15,000 a month"
# 22,newHR Intern,"Remote in Noida, Uttar Pradesh","Attending all meeting on time.
# Job Types: Part-time, Internship, Fresher.
# Arranging Session and problem solving.
# Opening ( 2 in 1 ) Account in yes Bank.","в‚№7,000 a month"
# 23,newBUS HELPER,"Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Volunteer, Internship, Fresher.
# Total work: 1 year (Preferred).","в‚№9,391 - в‚№15,000 a month"
# 24,newComputer Teacher Required,"Delhi, Delhi","Part-time hours: 30 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Fresher.
# Total work: 1 year (Preferred).",NA
# 25,newComputer Operator,"Delhi, Delhi","Data entry: 1 year (Preferred).
# Part-time hours: 40 per week.
# Higher Secondary(12th Pass) (Required).
# Delhi, Delhi: Reliably commute or planning to relocateвЂ¦","в‚№8,000 - в‚№20,000 a month"
# 26,Model for Jewelry and Apparel,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent.
# Gurgaon, Gurgaon, Haryana: Reliably commute or planning to relocate before starting work (Preferred).","в‚№8,000 - в‚№25,000 a month"
# 27,newNews Reporter,"Ghaziabad, Uttar Pradesh","Skills needed for the job - English and Hindi typing, good vocabulary in any of the languages.
# Part-time hours: 72 per week.
# Total work: 10 years (Preferred).","в‚№5,000 - в‚№15,000 a month"
# 28,newFemale Hindi Online Tutor,Remote,"Teach students how to apply Grammar, how to write the hindi, explaining quality .
# Ability to manage time effectively.
# Total work: 1 year (Preferred).",в‚№200 an hour
# 29,newComputer Teacher,"Remote in Ranchi, Jharkhand",Part-time hours: 14 per week.,"в‚№20,000 a month"
# 30,Content Writer- Web,"Jaipur, Rajasthan","Job Types: Full-time, Part-time, Regular / Permanent, Freelance, Internship, Fresher.
# Copy-editing and proof reading articles.
# Total work: 1 year (Preferred).","в‚№8,941 - в‚№15,000 a month"
# 31,newElectrical Support ( Fresher),"Greater Noida, Uttar Pradesh","Job Types: Full-time, Part-time.","в‚№12,000 - в‚№16,000 a month"
# 32,newDistillery job,"Delhi, Delhi","Part-time hours: 48 per week.
# Job Types: Part-time, Regular / Permanent, Contractual / Temporary, Freelance.
# I want an expert personnel in the field of creatingвЂ¦","в‚№25,000 a month"
# 33,newFemale Hindi Online Tutor,Remote,"Teach students how to apply Grammar, how to write the hindi, explaining quality .
# Ability to manage time effectively.
# Total work: 1 year (Preferred).",в‚№200 an hour
# 34,newSchool Transport Escort,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Contractual / Temporary.
# ALSO SHALL HAVE COMPLETE KNOWLEDGE OF BUSSES AND EVERYTHING.
# Total work: 1 year (Preferred).","в‚№17,000 - в‚№25,217 a month"
# 35,newEnthusiastic Volunteers,"Temporarily Remote in New Delhi, Delhi","Job Types: Part-time, Regular / Permanent, Volunteer, Internship, Fresher.
# Male/ Female, Experienced/ Fresher & Students who have interest in Social Work.",NA
# 36,Freelance Content Writer,"Delhi, Delhi","Job Types: Full-time, Part-time, Freelance.
# Write clear marketing copy to promote our products/services.
# Identify customers needs and gaps in our content andвЂ¦","в‚№5,000 - в‚№15,000 a month"
# 37,OB-Gynae - Medical writer - MCQs,"Delhi, Delhi","Part-time hours: 20 per week.
# Team player: must be able to work as per the editor and team leadвЂ™s instructions.
# Questions and work must be plagiarism free.","в‚№1,66,631 - в‚№6,75,817 a year"
# 38,Content Writer,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Internship, Fresher.
# Content writing: 1 year (Preferred).","в‚№15,000 - в‚№50,000 a month"
# 39,Content Writer,"Meerut, Uttar Pradesh","Part-time hours: 40 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.
# Submit work to editors for input and approval.","в‚№5,123 - в‚№8,233 a month"
# 40,Social Media (Part-Time/Freelancer),"New Delhi, Delhi","Part-time hours: 5 per week.
# Job Types: Part-time, Contractual / Temporary, Freelance, Internship.
# Social media marketing: 1 year (Preferred).","в‚№7,000 - в‚№15,000 a month"
# 41,newCopywriter,Remote,"Job Types: Part-time, Freelance, Internship.",NA
# 42,newTech Product Content Writer,Remote,"Part-time hours: 35 per week.
# Payment will be done after every article.
# Need a part-time freelance English content writer for a *tech product review site*.","в‚№9,000 - в‚№15,000 a month"
# 43,Computer operater,"Delhi, Delhi",Computer operators *monitor and control computer and electronic data processing equipment according to standardized operating instructions*.,"в‚№12,000 a month"
# 44,Excel Project Developer-Contract Position,"Remote in Punjabi Bagh, Delhi, Delhi","In Spreadsheet we need to add hours with key in for each employee, studentsвЂ™ classes even when they weekly get the schedule on hourly basis and determineвЂ¦","в‚№8,000 - в‚№15,000 a week"
# 45,Social Media Manager,"Remote in Bengaluru, Karnataka","Part-time hours: 30 per week.
# Handle all social media accounts.
# Manage all social media interns/employees.","в‚№3,000 - в‚№5,000 a month"
# 46,newData Entry Operator,"Mahim, Mumbai, Maharashtra","Part-time hours: 48 per week.
# Pay: Up to в‚№25,000.00 per month.
# Job Types: Full-time, Part-time, Regular / Permanent, Fresher.
# AGE LIMIT 18 TO 30 YRS.","в‚№25,000 a month"
# 47,Freelance & Part Time Editors,"New Delhi, Delhi",Careers Champak magazine is looking for freelance and partime editors for their book publishing division. Pls send your resume at jobseditorial@delhipressвЂ¦,NA
# 48,Data Entry Operator,"Temporarily Remote in Kochi, Kerala","Compiling, verifying accuracy and sorting information to prepare source data for computer entry.
# Entering customer and account data from source documents withinвЂ¦","в‚№9,547 - в‚№30,332 a month"
# 49,Freelancer Content Writer,"Gurgaon, Haryana","Job Types: Part-time, Contractual / Temporary, Freelance, Fresher.
# Develop grammatically flawless and informative content on different niche.","в‚№10,000 - в‚№15,000 a month"
# 50,newCall Center Executive,"New Delhi, Delhi","Part-time hours: 32 per week.
# Job Types: Full-time, Part-time, Freelance.
# Near Shanti palace hotel, New Delhi, Delhi: Reliably commute or planning to relocateвЂ¦","в‚№10,141 - в‚№15,000 a month"
# 51,Model for Jewelry and Apparel,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent.
# Gurgaon, Gurgaon, Haryana: Reliably commute or planning to relocate before starting work (Preferred).","в‚№8,000 - в‚№25,000 a month"
# 52,Internship in Content Writing,"Temporarily Remote in Delhi, Delhi","Full-time Internship which can result in pre-placement offers.
# Having excellent communication and presentation skills.
# Type: Part Time, Full Time.",NA
# 53,Business Associate,"Remote in Jamshedpur, Jharkhand","Part-time hours: 25 per week.
# Job Types: Full-time, Part-time, Regular / Permanent.
# Total work: 1 year (Preferred).","в‚№20,000 - в‚№50,000 a month"
# 54,newBUS HELPER,"Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Volunteer, Internship, Fresher.
# Total work: 1 year (Preferred).","в‚№9,391 - в‚№15,000 a month"
# 55,newDistillery job,"Delhi, Delhi","Part-time hours: 48 per week.
# Job Types: Part-time, Regular / Permanent, Contractual / Temporary, Freelance.
# I want an expert personnel in the field of creatingвЂ¦","в‚№25,000 a month"
# 56,Accounts Assistant,"New Delhi, Delhi+1 location","Shall have basic knowledge of accounts shall know how to operate computer very well.
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.",NA
# 57,Content Writer (Work From Home),"Remote in Chennai, Tamil Nadu","Job Types: Full-time, Part-time, Regular / Permanent.
# You have to write on various niches like software, technical, home products, etc.","в‚№15,000 - в‚№20,000 a month"
# 58,School Administrator,"Delhi, Delhi",We are looking for School Administrator with Graduate Degree in any stream along with 2-10 years of experience in the the same or relevant profile.,"в‚№25,788 - в‚№40,000 a month"
# 59,Bpo telecaller,"Remote in Bengaluru, Karnataka","Part-time hours: 48 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Volunteer, Internship, Fresher.
# Higher Secondary(12th Pass) (Preferred).","в‚№23,000 - в‚№26,000 a month"
# 60,newPersonal Assistant,"Delhi, Delhi","Part-time hours: 30 per week.
# Must be ok with exl.
# Should be ok with travel in delhi ncr and pan india if required.
# Total work: 1 year (Preferred).","в‚№35,000 - в‚№55,000 a month"
# 61,Computer Operator,"New Delhi, Delhi","Job Types: Full-time, Part-time.
# Experience of Computers (MS Word, Excel, Power Point), Emails, Good Typing Speed.","в‚№6,000 - в‚№10,000 a month"
# 62,newInventory Manager,"New Delhi, Delhi","Each and every physical stock should match with our stock reflecting with software data.*.
# Part-time hours: 5 per week.","в‚№2,000 - в‚№8,000 a month"
# 63,Policy Writing Internships,"New Delhi, Delhi",Who can apply вЂ“ Students pursuing or completed degree in any stream interested in Policy research and writing policy briefs are welcome to applyвЂ¦,NA
# 64,Excel Project Developer-Contract Position,"Remote in Punjabi Bagh, Delhi, Delhi","In Spreadsheet we need to add hours with key in for each employee, studentsвЂ™ classes even when they weekly get the schedule on hourly basis and determineвЂ¦","в‚№8,000 - в‚№15,000 a week"
# 65,newAccountant cum Office Assistant,"Gurgaon, Haryana","Looking for full-time Accountant cum office assistance with a good knowledge of Tally ERP .
# Maintaining office equipment as needed.","в‚№12,651 - в‚№33,780 a month"
# 66,newMTR Milling MachineOperator,"Sonipat, Haryana","Job Types: Full-time, Part-time, Regular / Permanent.
# Sonipat, Haryana: Reliably commute or planning to relocate before starting work (Required).","в‚№20,000 - в‚№28,000 a month"
# 67,newRequired Educators,"Temporarily Remote in Jaipur, Rajasthan","Part-time hours: 24 per week.
# You can work from home but you must have setup for online teaching (Laptop, Pen tablet and webcam).",NA
# 68,General administrative tasks,"Remote in Delhi, Delhi","You have high-speed internet and a computer less than 3 years old with updated software.
# Per day from 8-11 am PST (you must be a person who likes to stay upвЂ¦","в‚№25,000 a month"
# 69,Catalogue Executives,"Gurgaon, Haryana","All positions are based out of our Gurgaon office Catalogue Executives Your job involves surfing the net, gathering knowledge, sipping a coffee andвЂ¦.. Whoa,вЂ¦",NA
# 70,Marketing Manager,"Remote in Noida, Uttar Pradesh","Part-time hours: 20 per week.
# Go the extra mile (Go above and beyond, go beyond the call of duty, go get it done on time).","в‚№10,00,000 a year"
# 71,Lecturer,"Delhi, Delhi","Part-time hours: 3-4 per week.
# Delhi, Delhi: Reliably commute or planning to relocate before starting work (Preferred).
# Total work: 1 year (Preferred).",в‚№400 - в‚№500 an hour
# 72,.Net Developer (Part Time),"Remote in Delhi, Delhi+2 locations","Job Types: Part-time, Regular / Permanent, Freelance.
# NET Developer for 1 year.
# Write clean, testable code using .
# Total work: 1 year (Required).","в‚№5,000 - в‚№15,000 a month"
# 73,Social Media Manager and Content Creator,"New Delhi, Delhi","Job Types: Full-time, Part-time.
# Looking for tech savvy candidates with fluency in English and Hindi to write, create and manage content for social media, blogsвЂ¦","в‚№8,000 - в‚№15,000 a month"
# 74,Computer Teacher,"New Delhi, Delhi",The ability to deliver Computer Science at Institute is highly desirable and should have basic and advanced computer skills and programming languages likeвЂ¦,"в‚№400 - в‚№1,000 an hour"
# 75,Content Writer,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Internship, Fresher.
# Content writing: 1 year (Preferred).","в‚№15,000 - в‚№50,000 a month"
# 76,Quality Analyst,"Temporarily Remote in Gurgaon, Haryana","Part-time hours: 20-25 per week.
# Job Types: Part-time, Freelance.
# Strong knowledge of unit testing, smoke testing, sanity testing,re-testing, E2E testing,вЂ¦","в‚№10,000 - в‚№15,000 a month"
# 77,Computer operater,"Delhi, Delhi",Computer operators *monitor and control computer and electronic data processing equipment according to standardized operating instructions*.,"в‚№12,000 a month"
# 78,Office Manager,"Remote in Palam Vihar, Delhi, Delhi","Part-time hours: 20-25 per week.
# Education: Any one, as long as the candidate is well versed with basic computer knowledge and English Language.","в‚№7,000 - в‚№10,000 a month"
# 79,Investigator,"Remote in Chandigarh, Chandigarh","Total work: 10 years (Preferred).
# Investigators (Part-time, on contractual basis)*.
# Involves travel within India and could be state specific.","в‚№50,000 a month"
# 80,newwedding video editor,"Remote in Delhi, Delhi","Part-time hours: 60 per week.
# Job Types: Full-time / Part-time.
# Job Types: Full-time, Part-time.
# Min. 2 years of experience.
# Video Editing: 2 years (Preferred).","в‚№60,000 a month"
# 81,newAcademic Content Writer,"Remote in Guwahati, Assam","The candidate must properly carry out their responsibilities within the organization.
# Job Types: Full-time, Part-time, Regular / Permanent, Freelance,вЂ¦","в‚№7,000 - в‚№15,000 a month"
# 82,newAccounts Assistant,Remote,"Part-time hours: 20 per week.
# Job Types: Part-time, Regular / Permanent, Freelance.
# Looking for someone experience with bookkeeping and tax returns.","в‚№1,50,000 - в‚№2,00,000 a year"
# 83,Digital Designer,"Delhi, Delhi","Compensation on per design basis, regular work to be offered around 15-20 designs per month.
# Part-time hours: 10 per week.","в‚№4,000 - в‚№5,000 a day"
# 84,BUS COMPANY MANAGER / BUS TRANSPORT SUPERVISOR / SCHOOL BUS...,"Gurgaon, Haryana","Job Types: Full-time, Part-time, Regular / Permanent.
# Gurugram, Haryana: Reliably commute or planning to relocate before starting work (Required).","в‚№10,086 - в‚№20,284 a month"
# 85,Accounts Assistant,"Sarai Rohilla, Delhi, Delhi+1 location","Need an accounts executive who has complete knowledge of filling Gst, Esi / PF basic accounts and accounting also can work on excel completely, Should beвЂ¦","в‚№16,000 a month"
# 86,Academic Content Writer (Gurugram) (Work From Office),"Remote in Sohna, Haryana","Ability to research on the internet.
# Job Type вЂ“ Office Job (No WFH, freelancing or Part-time).
# Good Communication skills in English.","в‚№2,00,000 - в‚№4,00,000 a year"
# 87,newMarket Research Intern,"Temporarily Remote in Gurgaon, Haryana","Work on data entry.
# Part-time hours: 35 per week.
# Job Types: Full-time, Part-time, Internship.
# Interaction with Key Opinion Leaders.","в‚№12,000 - в‚№16,000 a month"
# 88,School Administrator,"Delhi, Delhi",We are looking for School Administrator with Graduate Degree in any stream along with 2-10 years of experience in the the same or relevant profile.,"в‚№25,788 - в‚№40,000 a month"
# 89,FACULTY FOR MANAGEMENT COURSES,"Jaipur, Rajasthan","Part-time hours: 20 per week.
# Job Types: Full-time, Part-time, Freelance.
# We are open to colleagues who have received (or are receiving) a Ph.D. in Marketing /вЂ¦","в‚№25,000 - в‚№60,000 a month"
# 90,newbackend,"New Delhi, Delhi","Backend office work, Must be good in using Ms Office, data entry, Computer Savy.
# Part time job starting from 20 June '22 - 10 July'22.",в‚№300 a day
# 91,newHR Executive,"Remote in Shahdara, Delhi, Delhi","Maintain employee records (attendance, EEO data etc.) according to policy and legal requirements.
# Salary will be between the range of 18,000-23,000 per month.","в‚№18,000 - в‚№23,000 a month"
# 92,newFreelance Content Writer,"Bengaluru, Karnataka","Part-time hours: 6 per week.
# Total work: 1 year (Required).","в‚№5,000 a month"
# 93,newTelecaller,"Ludhiana, Punjab","Job Types: Full-time, Part-time, Freelance, Fresher.
# CANDIDATE SHOULD HAVE BASIC KNOWLEDGE OF MS EXCEL and should be female.","в‚№20,000 a month"
# 94,newField verification executive,"Delhi, Delhi","Job Types: Part-time, Freelance.
# Higher Secondary(12th Pass) (Preferred).
# Total work: 1 year (Preferred).","в‚№9,000 - в‚№12,000 a month"
# 95,newCommunication consultant (Part-time),"Gurgaon, Haryana","The part-time role will require a commitment of 2 days per week up to three months.
# A minimum of 2+ years of work experience in communications, stakeholderвЂ¦",NA
# 96,General administrative tasks,"Remote in Delhi, Delhi","You have high-speed internet and a computer less than 3 years old with updated software.
# Per day from 8-11 am PST (you must be a person who likes to stay upвЂ¦","в‚№25,000 a month"
# 97,newHR Executive,"Remote in Dispur, Assam+3 locations","Part-time hours: 21-30 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Freelance.
# Candidates should fulfill target on time.","в‚№10,000 - в‚№12,000 a month"
# 98,Social Media and Marketing Intern,"Remote in Gurgaon, Haryana","Part-time hours: 10 per week.
# Job Types: Full-time, Part-time.
# Looking for a social media and marketing person to run promotions , target events for the brand,вЂ¦","в‚№8,000 - в‚№10,000 a month"
# 99,Math assessment developer,"Delhi, Delhi","Part-time hours: 20 per week.
# Job Types: Full-time, Part-time, Contractual / Temporary, Freelance, Fresher.
# \* Preparing Test questions for K-12 in the area ofвЂ¦","в‚№18,000 a month"
# 100,newGraphic Designer Intern (fresher),"New Delhi, Delhi","Part-time hours: 30 per week.
# Collaborate closely with our Brand Design team to translate the expression of our brand identity into our user experiences.","в‚№1,000 - в‚№2,000 a month"
# 101,newPart-time Nutritionist,"Green Park, Delhi, Delhi","Candidates are required to come to office 5 days a week (for 5 hours per day).
# Part-time hours: 30 per week.
# Total work: 5 years (Required).","в‚№8,000 - в‚№10,000 a month"
# 102,newInventory Manager,"New Delhi, Delhi","Each and every physical stock should match with our stock reflecting with software data.*.
# Part-time hours: 5 per week.","в‚№2,000 - в‚№8,000 a month"
# 103,newContent Writer's Paid Internship,"Remote in Guwahati, Assam","Part-time hours: 4-5 per week.
# Job Types: Part-time, Freelance, Internship, Fresher.
# Bonus: в‚№3000 based on quality of work after completion of three months +вЂ¦","в‚№5,500 a month"
# 104,newContent Writer,"Visakhapatnam, Andhra Pradesh","Candidates must have a good PC/Laptop with an internet connection.
# Job Types: Full-time, Part-time.
# Excellent interpersonal and English written skills.","в‚№12,000 - в‚№15,000 a month"
# 105,Business Development Officer,"Remote in Gautam Budh Nagar, Uttar Pradesh","Comfortable using a computer for various tasks.
# Job Types: Part-time, Contractual / Temporary.
# To excel in this role you should be an active listener, have aвЂ¦","в‚№80,000 - в‚№1,00,000 a month"
# 106,Creative Copywriter,"Gurgaon, Haryana","*Stay up to speed with relevant trends within the retail/eCommerce industry.*.
# Job Types: Full-time, Part-time, Freelance.
# Online store banners and headlines.","в‚№25,000 - в‚№40,000 a month"
# 107,newGraphic Designer Intern (fresher),"New Delhi, Delhi","Part-time hours: 30 per week.
# Collaborate closely with our Brand Design team to translate the expression of our brand identity into our user experiences.","в‚№1,000 - в‚№2,000 a month"
# 108,newSocial Media Graphics Designer,"Delhi, Delhi","Must have above average communication skills.
# Internship type: Full-time (hybrid).
# Part-time hours: 50 per week.
# Should have a flair for social media marketing.","в‚№14,000 - в‚№18,000 a month"
# 109,newAccountant,"Gurgaon, Haryana","Part-time hours: 60 per week.
# Publish financial statements in time.
# Hands-on experience with accounting software like TALLY.
# Knowledge of GST, TDS etc.","в‚№17,000 - в‚№20,000 a month"
# 110,Video Editor - Top 10 Style,"Delhi, Delhi","Part-time hours: 20 per week.
# Regular Work and Good Pay per project.
# We are looking for a Youtube editor who can edit top 10 style YouTube videos.","в‚№8,350 - в‚№29,097 a month"
# 111,Subject Matter Experts/Academic Writers,"Noida, Uttar Pradesh","This is both Full-time/Part time job opportunity depending on the convenience of the candidate.
# Digiversal is looking for full time writers/researchers to workвЂ¦",NA
# 112,newNeed Tutors,"Lucknow, Uttar Pradesh","Part-time hours: 36 per week.
# Job Types: Part-time, Freelance, Fresher.
# Lucknow, Uttar Pradesh: Reliably commute or planning to relocate before starting work вЂ¦","в‚№6,000 - в‚№20,000 a month"
# 113,newTeam Member,"Noida, Uttar Pradesh+5 locations","*Performs order processing вЂ“ Process the recipes accurately as per the process in a fast and timely manner.
# 10*. Ensures fast and timely service to customers,вЂ¦","в‚№13,000 - в‚№15,000 a month"
# 114,newBusiness Development Intern,"Noida, Uttar Pradesh","Job Types: Full-time, Part-time, Internship.
# Job Types*: Full-time, Part-time, Internship, Fresher.
# Learns and becomes proficient on internal software systems.",NA
# 115,newEsi And Pf Consultant,"Greater Noida, Uttar Pradesh","Part-time hours: 20 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Internship, Fresher.","в‚№8,000 - в‚№20,000 a month"
# 116,newDistrict Manager,"Remote in Dhanbad, Jharkhand","Part-time hours: 21 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Fresher.
# Dhanbad, Dhanbad - 826001, Jharkhand: Reliably commute or planningвЂ¦","в‚№20,000 a month"
# 117,newArticle Writer,"Remote in Jammu, Jammu and Kashmir",I recently started this word and I need hardworking and trustworthy people who know the knowledge of how to type and post an article regarding news with noвЂ¦,NA
# 118,Business Development (Part-time WFH),Remote,"Be available for minimum of 4 hours per day.
# Part-time hours: 4 per week.
# Maintain call records and follow up as per schedule.","в‚№10,000 a month"
# 119,newFinance Assistant,"Remote in Bengaluru, Karnataka",We are Hiring for Leader's who have good experience in Banking and Any Financial sector any apply and also having very good customer contact .,"в‚№30,000 - в‚№50,000 a month"
# 120,newOnline Marketing Executive,"New Delhi, Delhi","Job Types: Full-time, Part-time.
# We are looking for Good & Experienced Candidate proficient in online selling on various ecommerce websites like Amazon,вЂ¦","в‚№9,988 - в‚№37,669 a month"
# 121,Content Writer,+1 locationRemote,"Part-time hours: 45 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Volunteer, Internship, Fresher.","в‚№3,000 a month"
# 122,Real Estate Agent,"Delhi, Delhi","All candidates must be vaccinated and use facemask and maintain social distance on daily basis.
# Job Types: Full-time, Part-time, Freelance, Fresher.","в‚№20,000 a month"
# 123,Content Writer Intern,"New Delhi, Delhi","Job Types: Part-time, Internship.
# Prepare blogs for the website.
# Prepare content for email campaigns.
# Co-ordinate with the marketing team for the content.","в‚№1,000 a month"
# 124,Subject Matter Expert,"Delhi, Delhi","Prefer candidates with Math Background(Undergrads can also apply).
# Job Types: Part-time, Contractual / Temporary, Freelance, Fresher.","в‚№18,000 a month"
# 125,newCashier/Sales Assistant,"Delhi, Delhi","Job Types: Full-time, Part-time.
# Yes vivid protocols are followed.
# Delhi, Delhi - 110051, Delhi: Reliably commute or planning to relocate before starting work вЂ¦","в‚№12,000 - в‚№15,000 a month"
# 126,Marketing Manager,"Remote in Noida, Uttar Pradesh","Part-time hours: 20 per week.
# Go the extra mile (Go above and beyond, go beyond the call of duty, go get it done on time).","в‚№10,00,000 a year"
# 127,newData Entry Work,"New Alipore, Kolkata, West Bengal","Job Types: Full-time, Part-time.
# Higher Secondary(12th Pass) (Preferred).","в‚№8,000 - в‚№9,000 a month"
# 128,Fresh Faces For Instagram Profile Collaboration,"Delhi, Delhi","Part-time hours: 35 per week.
# Modeling & Styling For The Ethnic Garment Shoots On 30% Collaboration From Scratch.
# Modeling For New Creative Videos/Reels.","в‚№2,000 a month"
# 129,Freelance Content Writer,"Remote in Faridabad, Haryana","Part-time hours: 28 per week.
# Job Types: Part-time, Freelance, Internship.
# The work will be contract based (Avg Monthly income will be 30-15k), more.","в‚№15,000 a month"
# 130,Academic Content Writer (Gurugram) (Work From Office),"Remote in Sohna, Haryana","Ability to research on the internet.
# Job Type вЂ“ Office Job (No WFH, freelancing or Part-time).
# Good Communication skills in English.","в‚№2,00,000 - в‚№4,00,000 a year"
# 131,HR and Operation Head Intern,Remote,"Generate reports and data of the team.
# Job Types: Full-time, Part-time, Internship, Fresher.
# Ensure that the project is delivered on time, within scope, andвЂ¦",NA
# 132,newBusiness Development Executive (BDE),"Remote in Noida, Uttar Pradesh","Good communication skills (English or Hindi both will work).
# Training sessions that will be provided by us and 35 account is minimum target,.","в‚№10,000 a month"
# 133,Content Writer,"New Delhi, Delhi","Part-time hours: 40 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Freelance, Volunteer, Internship, Fresher.
# Total work: 1 year (Preferred).","в‚№9,000 - в‚№15,000 a month"
# 134,newData Entry Operator,"Sahar, Mumbai, Maharashtra","Part-time hours: 48 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Fresher.
# AGE LIMIT 18 TO 30 YRS.
# Microsoft Office: 1 year (Preferred).","в‚№24,000 a month"
# 135,Freelance & Part Time Editors,"New Delhi, Delhi",Careers Champak magazine is looking for freelance and partime editors for their book publishing division. Pls send your resume at jobseditorial@delhipressвЂ¦,NA
# 136,BLOOD BANK OFFICER/INCHARGE (PART TIME),"New Delhi, Delhi","Job Code : DHLI/HR/18/05/2022 No of Position : 01 Job Description MBBS, MD(Pathology) with min 4-5 yrs exp as Blood Bank Officer/Incharge in NABHвЂ¦",NA
# 137,newEvent Planner,"Gurgaon, Haryana","Part-time hours: 40 per week.
# Plan and organize events with attention to financial and time constraints.
# Job Types: Full-time, Part-time, Regular / Permanent,вЂ¦","в‚№15,000 a month"
# 138,newVideo Editor,"Remote in Delhi, Delhi","Part-time hours: 30 per week.
# Job Types: Part-time, Regular / Permanent, Contractual / Temporary.
# Strong time management, organization, problem-solving, andвЂ¦","в‚№9,000 a month"
# 139,newMobilizer,"Remote in Alwar, Rajasthan","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Internship, Fresher.
# Data collection and Call to students.","в‚№8,000 - в‚№15,000 a month"
# 140,newSchool Transport Supervisor,"Gurgaon, Haryana","Job Types: Full-time, Part-time.
# Manage school busses, Driver/ Helper/ Other Busses.
# Gurugram, Gurugram - 122006, Haryana: Reliably commute or planning toвЂ¦","в‚№23,000 a month"
# 141,Sales Assistant,"Remote in Delhi, Delhi","Part-time hours: 4 per week.
# 7000/- as stipend and companyвЂ™s training certificate, on successfully selling life insurance policy with minimum premium of Rs.","в‚№7,000 - в‚№20,000 a month"
# 142,Gym Receptionist,"Delhi, Delhi",The candidate must know about the basic computer and know a bit about excel e.g familiar with the data entries.,"в‚№10,000 - в‚№12,000 a month"
# 143,newHR Recruiter,"Noida, Uttar Pradesh","Part-time hours: 4 per week.
# This role is for part time from Noida office.
# Responsible for achieving a good conversion ratio of submitting into interview andвЂ¦","в‚№8,086 - в‚№20,000 a month"
# 144,newEsi And Pf Consultant,"Greater Noida, Uttar Pradesh","Part-time hours: 20 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Internship, Fresher.","в‚№8,000 - в‚№20,000 a month"
# 145,newTelesales,"Kailash, Delhi+1 location","Part-time hours: 54 per week.
# Job Types: Full-time, Part-time, Freelance, Fresher.
# Higher Secondary(12th Pass) (Preferred).
# Total work: 1 year (Required).","в‚№8,000 - в‚№25,000 a month"
# 146,newHR Executive,"Delhi, Delhi","Job Types: Full-time, Part-time.
# Yes vivid protocols are followed.
# Delhi, Delhi, Delhi: Reliably commute or planning to relocate before starting work (PreferredвЂ¦","в‚№15,000 - в‚№25,000 a month"
# 147,Part Time Calling profile,"Delhi, Delhi","Part-time hours: 30 per week.
# Those who are looking for part time work.
# Okhla, Delhi, Delhi, Delhi - 110020, Delhi: Reliably commute or planning to relocateвЂ¦","в‚№8,000 - в‚№10,000 a month"
# 148,newPHP Developer,Remote,"Duration: * Long Term (minimum 1 year).
# Job Types: Full-time, Part-time.
# Domain: * Digital Marketing for US Colleges.
# PHP Developing: 5 years (Preferred).","в‚№8,00,000 - в‚№13,00,000 a year"
# 149,Content Writer,"Remote in Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Internship.
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.",NA
# 150,Transport Supervisor,"Mayur Vihar, Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent.
# E п‚· Oversee purchases of repair parts and department supplies.
# Total work: 1 year (Preferred).","в‚№19,867 - в‚№20,034 a month"
# 151,newVideo Editor,"Chandigarh, Chandigarh","Part-time hours: 25 per week.
# Higher Secondary(12th Pass) (Preferred).
# Video Editing: 1 year (Preferred).
# Total work: 1 year (Preferred).","в‚№10,019 - в‚№20,000 a month"
# 152,Computer Teacher,"Laxmi Nagar, Delhi, Delhi","We are looking for a computer trainer who has a good command of adv excel basic computer Tally.
# Job Types: Full-time, Part-time.
# Total work: 1 year (Preferred).","в‚№12,000 - в‚№18,000 a month"
# 153,newSocial Media Executive,"Greater Kailash II, Delhi, Delhi","Job Types: Full-time, Part-time.
# Social media marketing: 1 year (Preferred).
# Total work: 1 year (Preferred).","в‚№20,000 - в‚№30,000 a month"
# 154,newHuman Resources Internship,"New Delhi, Delhi","Part-time hours: 30 per week.
# Available immediately to start with the internship position.
# Helping the organization expand their reach.","в‚№1,000 - в‚№2,000 a month"
# 155,Telecaller,"Connaught Place, Delhi, Delhi","Part-time hours: 30 per week.
# Updating feedback on excel sheet.
# Good communication skills required ( English).
# Calling required from 12noon to 5pm.","в‚№8,000 a month"
# 156,Social Media Manager,"New Delhi, Delhi","Keep pace with social media and internet marketing industry trends and developments.
# Part-time hours: 40 per week.
# Social Media Occupations: 1 year (Preferred).",NA
# 157,Sales Manager,"New Delhi, Delhi","Part-time hours: 45 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Internship.
# Sharp Eye Infotech is Looking for the Sales and MarketingвЂ¦","в‚№1,38,536 - в‚№6,69,016 a year"
# 158,newContent Writer,"Green Park, Delhi, Delhi","Part-time hours: 20 per week.
# It can be home based job or full time office job.
# Job Types: Full-time, Part-time, Freelance.
# Content writing: 1 year (Preferred).","в‚№12,000 - в‚№15,000 a month"
# 159,Warehouse Assistant,"Tihar, Delhi","Part-time hours: 4 per week.
# We have urgent requirement for warehouse Worker both male & Female for Part Time as well as Full Time.","в‚№5,000 a month"
# 160,Human Resources Executive,"Remote in Delhi, Delhi","Searching for the right candidate as per the client requirement through various job portal.
# Sourcing as per the requisitions for various departments and furtherвЂ¦",NA
# 161,newHR Internship,"Remote in Mumbai, Maharashtra","Part-time hours: 25 per week.
# Pay: в‚№5,000.00 per month.
# Job Types: Part-time, Internship, Fresher.
# Documentation & Negotiation Maintain Daily tracker .","в‚№5,000 a month"
# 162,Website Manager,"Remote in Delhi, Delhi","Part-time hours: 20 per week.
# Turn raw data into actionable insights (funnel conversion, campaigns, A/B tests, website behavior, customer journey experiments).","в‚№40,000 - в‚№75,000 a month"
# 163,feild executive,"New Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Contractual / Temporary, Freelance, Fresher.
# Job Type : - Full Time & Part Time.","в‚№12,000 - в‚№15,000 a month"
# 164,Creative,India,"Both full-time and part-time jobs are available.
# By adjusting your teaching style to each userвЂ™s individual skill level, you maximise his or her understandingвЂ¦",NA
# 165,newPHP Developer,Remote,"Duration: * Long Term (minimum 1 year).
# Job Types: Full-time, Part-time.
# Domain: * Digital Marketing for US Colleges.
# PHP Developing: 5 years (Preferred).","в‚№8,00,000 - в‚№13,00,000 a year"
# 166,Content Writer,"Remote in Delhi, Delhi","Job Types: Full-time, Part-time, Regular / Permanent, Internship.
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.",NA
# 167,newInterior Designer,"Delhi, Delhi","Part-time hours: 20 per week.
# WeвЂ™re looking for a candidate who can join us with zeal to learn something in a new prospect.
# Total work: 2 years (Required).","в‚№25,000 a month"
# 168,Freelancer Content Writer,"Gurgaon, Haryana","Job Types: Part-time, Contractual / Temporary, Freelance, Fresher.
# Develop grammatically flawless and informative content on different niche.","в‚№10,000 - в‚№15,000 a month"
# 169,newPower BI Developer,Remote,"This will be a contractual role, the candidate must possess at least 2 years of experience, creating and developing Dashboards in Power BI by connecting to aвЂ¦","в‚№1,000 - в‚№3,000 a day"
# 170,Business Development Officer,"Remote in Gautam Budh Nagar, Uttar Pradesh","Comfortable using a computer for various tasks.
# Job Types: Part-time, Contractual / Temporary.
# To excel in this role you should be an active listener, have aвЂ¦","в‚№80,000 - в‚№1,00,000 a month"
# 171,newSEO Executive,"Roorkee, Uttarakhand","Weekly tasks will be provided to deliver in the respective time span.
# Job Types: Full-time, Regular / Permanent, Fresher.
# Total work: 1 year (Preferred).","в‚№15,500 - в‚№25,500 a month"
# 172,newClient Servicing Executive,"Gurgaon, Haryana","Part-time hours: 40 per week.
# Job Types: Full-time, Part-time, Regular / Permanent, Internship, Fresher.
# Inspiring repeat business from clients.","в‚№15,000 a month"
# 173,newContent Writer,"Remote in Bengaluru, Karnataka","Attitude and passion to come up with fresh and innovative ideas for great and interesting content.
# Employment Type: Full Time/Part Time.","в‚№3,00,000 - в‚№6,00,000 a year"
# 174,Tender Executive,"Ashok Vihar, Delhi, Delhi","Job Types: Full-time, Part-time.
# Ashok Vihar, Delhi - 110052, Delhi: Reliably commute or planning to relocate before starting work (Preferred).","в‚№20,000 - в‚№25,000 a month"
# 175,newHuman Resources Internship,"New Delhi, Delhi","Part-time hours: 30 per week.
# Available immediately to start with the internship position.
# Helping the organization expand their reach.","в‚№1,000 - в‚№2,000 a month"
# 176,Digital Marketing Intern,"Dwarka, Delhi, Delhi","Job Types: Full-time, Part-time, Internship.
# We are hiring interim candidate also who passed out and have any diploma in digital marketing.","в‚№9,000 - в‚№22,000 a month"
# 177,Marketing Intern,+1 locationRemote,"Part-time hours: 25-30 per week.
# Stipend : в‚№2500-10000 /- For Showdoctors.com ( Depends on joining type).
# Encourage Medical Equipment Suppliers/ Doctors to beвЂ¦","в‚№10,000 a month"
# 178,newCustomer Support Executive cum Telecalling,"Chennai, Tamil Nadu","Job Types: Part-time, Regular / Permanent, Fresher.
# The primary job of a *Customer Support Executive* is to *address customer issues and resolve them in aвЂ¦","в‚№25,000 - в‚№35,000 a month"
# 179,newCompetitive Programming with C++,Remote,"Job Types: Part-time, Contractual / Temporary, Freelance.
# Required Competitive Programming with C++ Trainer who is expert in topics with Problem Solving skills:вЂ¦",в‚№500 - в‚№800 an hour
